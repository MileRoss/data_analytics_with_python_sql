# %% [markdown]
# # Web Scraping

# %% [markdown]
# ![legtsgo](https://media.giphy.com/media/dwmNhd5H7YAz6/giphy.gif)

# %% [markdown]
# By the end of this lesson, you will be able to:
#
# - Identify the primary components of web technologies and their roles: HTML, CSS, and JavaScript.
# - Explain the hierarchical structure of HTML and the significance of tags, attributes, and their relationship.
# - Utilize the **requests** and **Beautiful Soup** libraries to scrape data from a static web page.
# - Construct and execute a script to scrape data from a webpage and export it into a structured text file using the pandas library.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Web-Scraping" data-toc-modified-id="Web-Scraping-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Web Scraping</a></span><ul class="toc-item"><li><span><a href="#What-is-Web-Scraping" data-toc-modified-id="What-is-Web-Scraping-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>What is Web Scraping</a></span></li><li><span><a href="#Web-structure" data-toc-modified-id="Web-structure-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Web structure</a></span></li><li><span><a href="#HTML" data-toc-modified-id="HTML-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>HTML</a></span><ul class="toc-item"><li><span><a href="#Exploring-Web-Page-Structures" data-toc-modified-id="Exploring-Web-Page-Structures-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Exploring Web Page Structures</a></span></li><li><span><a href="#Fact-1:-HTML-is-Built-on-Tags" data-toc-modified-id="Fact-1:-HTML-is-Built-on-Tags-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Fact 1: HTML is Built on Tags</a></span></li><li><span><a href="#Fact-2:-Tags-Can-Have-Attributes" data-toc-modified-id="Fact-2:-Tags-Can-Have-Attributes-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Fact 2: Tags Can Have Attributes</a></span></li><li><span><a href="#Fact-3:-Tags-Can-Be-Nested" data-toc-modified-id="Fact-3:-Tags-Can-Be-Nested-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Fact 3: Tags Can Be Nested</a></span></li><li><span><a href="#Selecting-Specific-Elements-in-Web-Scraping" data-toc-modified-id="Selecting-Specific-Elements-in-Web-Scraping-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Selecting Specific Elements in Web Scraping</a></span></li></ul></li><li><span><a href="#Web-Scraping-with-Python" data-toc-modified-id="Web-Scraping-with-Python-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Web Scraping with Python</a></span><ul class="toc-item"><li><span><a href="#Requests:-Fetching-a-Web-Page" data-toc-modified-id="Requests:-Fetching-a-Web-Page-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Requests: Fetching a Web Page</a></span></li><li><span><a href="#Parsing-HTML-with-Beautiful-Soup" data-toc-modified-id="Parsing-HTML-with-Beautiful-Soup-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Parsing HTML with Beautiful Soup</a></span><ul class="toc-item"><li><span><a href="#Extracting-Data" data-toc-modified-id="Extracting-Data-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>Extracting Data</a></span></li><li><span><a href="#More-filtering-options" data-toc-modified-id="More-filtering-options-1.4.2.2"><span class="toc-item-num">1.4.2.2&nbsp;&nbsp;</span>More filtering options</a></span></li><li><span><a href="#Creating-a-DataFrame-with-the-data" data-toc-modified-id="Creating-a-DataFrame-with-the-data-1.4.2.3"><span class="toc-item-num">1.4.2.3&nbsp;&nbsp;</span>Creating a DataFrame with the data</a></span></li><li><span><a href="#💡-Check-for-understanding" data-toc-modified-id="💡-Check-for-understanding-1.4.2.4"><span class="toc-item-num">1.4.2.4&nbsp;&nbsp;</span>💡 Check for understanding</a></span></li><li><span><a href="#Scraping-many-pages" data-toc-modified-id="Scraping-many-pages-1.4.2.5"><span class="toc-item-num">1.4.2.5&nbsp;&nbsp;</span>Scraping many pages</a></span></li><li><span><a href="#CSS-selectors" data-toc-modified-id="CSS-selectors-1.4.2.6"><span class="toc-item-num">1.4.2.6&nbsp;&nbsp;</span>CSS selectors</a></span></li></ul></li><li><span><a href="#More-examples" data-toc-modified-id="More-examples-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>More examples</a></span><ul class="toc-item"><li><span><a href="#BBC" data-toc-modified-id="BBC-1.4.3.1"><span class="toc-item-num">1.4.3.1&nbsp;&nbsp;</span>BBC</a></span></li></ul></li></ul></li><li><span><a href="#Comments" data-toc-modified-id="Comments-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Comments</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#Further-materials" data-toc-modified-id="Further-materials-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Further materials</a></span><ul class="toc-item"><li><span><a href="#How-to-Solve-a-403-Error" data-toc-modified-id="How-to-Solve-a-403-Error-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>How to Solve a 403 Error</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## What is Web Scraping

# %% [markdown]
# Web scraping is a method employed by data analysts and developers to retrieve information from web pages. It involves fetching a web page and then parsing that page to obtain desired information. This technique is especially useful when the desired data isn't available through APIs. The extracted data can then be cleaned, analyzed, or stored in databases for further data analytics tasks.

# %% [markdown]
# ## Web structure

# %% [markdown]
# The fundamental web technologies that form the structure of the websites we aim to scrape are:
#
# - **HTML**: Standing as the backbone of almost all websites, HTML, the core markup language, is instrumental in creating web pages. It houses all the content available on a webpage.
#
# - **CSS**: This stylesheet language works alongside HTML, taking charge of the presentation aspect of the webpages. It controls how HTML elements are displayed, setting the stage for a visually pleasing and organized web interface.
#
# - **JavaScript**: Adding a dynamic touch to the websites, JavaScript comes into play to create interactive and animated content. This programming language has the power to alter webpage content even after it has loaded, bringing a dynamic and responsive element to web designs.
#
# In this lesson, we will work with the HTML from the websites.

# %% [markdown]
# ## HTML

# %% [markdown]
# In the realm of web scraping, understanding HTML (Hypertext Markup Language) is crucial.
#
# HTML is the standard markup language used to create web pages. Think of it as the skeleton or blueprint of a website. It structures content on the web, defining elements like paragraphs, headings, links, lists, and images. These elements are represented by "tags", which enclose content to give it meaning and context.
#
# When web scraping, you'll often navigate through this HTML structure to pinpoint and extract the exact data you need. Tools like web browsers' "Inspect" or "View Source" features allow you to see the underlying HTML of a page, which is invaluable when determining how to access specific pieces of content programmatically.

# %% [markdown]
# ![](https://github.com/data-bootcamp-v4/lessons/blob/main/img/html.png?raw=true)

# %% [markdown]
# ### Exploring Web Page Structures
#
# To inspect the underlying HTML of a web page, right-click anywhere on the page. Choose "View Page Source" in browsers like Chrome or Firefox. For Internet Explorer, choose "View Source," and for Safari, select "Show Page Source." (In Safari, if this option isn't visible, navigate to Safari Preferences, click on the Advanced tab, and enable "Show Develop menu in menu bar.")
#
# To embark on your web scraping journey, you just need to grasp **three foundational aspects** of HTML.

# %% [markdown]
# ### Fact 1: HTML is Built on Tags
#
# At its core, HTML is composed of content enveloped in `<tags>`. It typically houses the textual content we aim to scrape, highlighted by these "tags" enclosed by angle brackets. These tags give structure and meaning, instructing the browser on how to present the content. The acronym "HTML" stands for Hyper Text Markup Language.
#
# HTML follows a tree-like structure, encompassing parent tags, child tags, and sibling tags:
# ```
# <html>
#     <head>
#         <title>Page Title</title>
#     </head>
#     <body>
#         <h1>My First Heading</h1>
#         <p>My first paragraph.</p>
#     </body>
# </html>
# ```
#
# For instance, consider the `<strong>` tag, signaling bold formatting. If "Jan. 21" is encapsulated between an opening `<strong>` tag and its corresponding closing `</strong>` tag, it denotes where the bold styling begins and ends. This pair of tags instructs the browser to render the enclosed text, "Jan. 21", in bold.
#
# Tags come in various types, each suited to encapsulate specific content:
#  * **Headings**: `<h1>`, `<h2>`, `<h3>`, `<h4>`...
#  * **Phrasing**: `<b>`, `<strong>`, `<sub>`, `<i>`, `<a>`...
#  * **Embedded Content**: `<audio>`, `<img>`, `<video>`, `<iframe>`...
#  * **Tabulated Data**: `<table>`, `<tr>`, `<td>`, `<tbody>`...
#  * **Page Sections**: `<header>`, `<section>`, `<nav>`, `<article>`...
#  * **Metadata and Scripts**: `<meta>`, `<title>`, `<script>`, `<link>`...

# %% [markdown]
# ### Fact 2: Tags Can Have Attributes
#
# HTML tags can possess "attributes," which are defined within the opening tag itself.
#
# Examine the following examples:
#
# - `<span class="short-desc">`: Here, the `<span>` tag has a `class` attribute with the value "short-desc".
# - `<div> Zapas Marca Joma X54 </div>`: This tag doesn't contain any attributes.
# - `<div class="price-item" id="offer"> Zapas Marca Joma X54 </div>`: The `div` tag here has two attributes - `class` with the value "price-item" and `id` with the value "offer".
# - `<a class="text-monospace" id="name_132" href="http://www.example.com"> Page Content </a>
# `: This `div` tag encompasses the following attributes:
#     + `class`: With the value "text-monospace". Remember, the class isn't unique across the page.
#     + `id`: With the value "name_132". IDs are meant to be unique identifiers for tags on the page.
#     + `href`: With the value www.example.com. The href commonly represents a link to another section of the page or to an external website.
#
# **Key Notes**:
# - The `id` attribute should be unique for a tag; no two tags should share the same `id`.
# - The `class` attribute isn't meant to be unique. Instead, it often groups tags exhibiting similar behavior or styles.
#
# For web scraping purposes, **understanding the semantics** behind terms like `<span>`, `class`, or `short-desc` **isn't crucial**. The key takeaway is recognizing that tags can possess attributes and understanding their structural representation. When extracting content, our goal is to pinpoint the right tags within a webpage's HTML.

# %% [markdown]
# **Other commonly used attributes in HTML**
#
# Several attributes in HTML provide additional information or modify elements. Some of these frequently used attributes include:
#
#  * **`dir`**: Determines the text direction within an element, allowing for either forward or backward writing.
#  * **`lang`**: Designates the language of the content within an element.
#  * **`style`**: Applies inline styling to an element (Note: This shouldn't be mixed up with the `<style>` tag).
#  * **`title`**: Offers supplementary details about an element, often displayed as a tooltip (Important: This is distinct from the `<title>` tag).
#
# ...and many more.

# %% [markdown]
# ### Fact 3: Tags Can Be Nested
#
# Imagine the following segment of HTML code:
#
# `Hello <strong><em>Ironhack</em> students</strong>`
#
# Here, the phrase **Ironhack students** would be displayed in bold since it resides between the `<strong>` and `</strong>` tags. Additionally, the word ***Ironhack*** would be italicized due to the `<em>` tag, which signifies italic formatting. However, the word "Hello" remains unaffected by any formatting, as it lies outside both the `<strong>` and `<em>` tags. This results in the display:
#
# Hello ***Ironhack* students**
#
# This example illustrates a key principle: **tags influence the text from their opening to their closing points,** even if they are nested within other tags.

# %% [markdown]
# ### Selecting Specific Elements in Web Scraping
#
# When diving into web scraping, it's essential to target specific elements efficiently. To hone in on the precise content you need, consider filtering tags based on:
#
#  * **Tag Name**: The main type of the element (e.g., `<div>`, `<a>`, `<p>`).
#  * **Class**: A descriptor that groups multiple elements with similar characteristics.
#  * **ID**: A unique identifier assigned to a particular element.
#  * **Other Attributes**: Additional properties like `href`, `title`, or `lang` that can further specify the elements of interest.

# %% [markdown]
# ## Web Scraping with Python

# %% [markdown]
# In this lesson, we'll use the `requests` library to fetch web pages and `Beautiful Soup` from the `bs4` package to parse these pages and extract information.

# %% [markdown]
# Ensure you've installed the required packages:

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /Users/milenko/anaconda3/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /Users/milenko/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/milenko/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/milenko/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/milenko/anaconda3/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/milenko/anaconda3/lib/python3.11/site-packages (from requests) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in /Users/milenko/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.4)

# %% [markdown]
# ### Requests: Fetching a Web Page

# %% [markdown]
# First, we use the `requests` library to fetch the content of a webpage.

# %%
import requests

url = "https://www.decathlon.com/collections/mountain-bikes"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# The provided code retrieves the webpage content from the given URL and saves it in a `response` object. This object possesses either a `text` or `content` attribute, holding the HTML code similar to what we observe when inspecting the source in a web browser.

# %%
response.content
# Out:
# b'\n\n\n\n\n\n<!doctype html>\n<!--[if IE 8]><html class="no-js lt-ie9" lang="en"> <![endif]-->\n<!--[if IE 9 ]><html class="ie9 no-js" lang="en"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en"> <!--<![endif]-->\n<head>\n  \n  <meta charset="utf-8">\n\n  \n  <!-- Title and description ============================================= -->\n  \n    <title>\n    Mountain Bikes | Decathlon\n    </title>\n  \n\n  \n  \n  <link rel="preconnect" href="//cdn.dynamicyield.com">\n  <link rel="preconnect" href="//st.dynamicyield.com">\n\n  \n  \n    \n    <script async id="adeptmind-js" src="//www.decathlon.com/cdn/shop/t/242/assets/adept-shop-ui.js?v=161985829706692883941707861092"></script>\n  \n\n  \n  <script async type="application/javascript" src="https://saa.wooly.com/wooly-analytics.js?token=wwjmqk1wqu9ldux4bfa5nlbqunfqzz09tBJeXPlRhn5W4aclKg0rqLGzWcz4Vo&source=shopify_checkout"></script>\n\n  \n  <script async src="//www.decathlon.com/cdn/shop/t/242/assets/modernizr.min.js?v=137617515274177302221667891820"></script>\n\n  \n  <script type="module" src="//www.decathlon.com/cdn/shop/t/242/assets/built-lazy-images.js?v=65193528714826927711667891934"></script>\n\n  <script src="//www.decathlon.com/cdn/shop/t/242/assets/jquery.min.js?v=74721525869110791951667891788" type="text/javascript"></script>\n\n  \n\n  \n  \n\n  \n  \n\n  <style type="text/css">.de-headerSection{position:sticky;top:0;z-index:1000}.de-header2-signin{display:none !important}.cd-popup{position:fixed;top:-100%}.message-slider{height:31px;text-align:center}.de-header2-right{display:flex}.de-MenuBar-label{font-size:16px}.de-header2-box{font-family:avalonbold,Helvetica Neue,Helvetica,Arial,sans-serif;border:1px solid #bababa;text-align:left;margin-right:22px;margin-top:auto;margin-bottom:auto;padding-left:6%;padding-right:4%;width:7vw;min-width:104px;height:35px;font-size:16px}.de-header2-box:hover{background-color:#ebebeb}.de-header2-box>svg{vertical-align:middle;margin-right:4%}.de-MenuBar-action>svg{position:relative;right:-2px}.de-PageWrap-subHeader>.de-PageWrap-logoImage{height:47px !important}.de-header2-right>.de-MenuBar-action{padding:0;height:47px;width:58px}.de-header2-right>.de-MenuBar-action--primary:before{transform:translateX(-320%) skewX(-10deg);left:45%}.de-header2-signin{display:none}#navigation-2_0 .de-PageWrap-menu{top:72px}.de-messageBarInner{background-color:#1f1f1f}.de-PageWrap-subHeader{justify-content:space-between}.de-PageWrap-menu{width:100%}.de-searchModal{display:none}.columns.is-mobile>.column.is-full{flex:none;width:100%}.columns.is-mobile>.column.is-three-quarters{flex:none;width:75%}.columns{margin-left:-0.75rem;margin-right:-0.75rem;margin-top:-0.75rem}.columns:last-child{margin-bottom:-0.75rem}.columns:not(:last-child){margin-bottom:calc(1.5rem - 0.75rem)}.columns.is-centered{justify-content:center}.columns.is-gapless{margin-left:0;margin-right:0;margin-top:0}.columns.is-gapless>.column{margin:0;padding:0 !important}.columns.is-gapless:last-child{margin-bottom:0}.columns.is-mobile{display:flex}.columns.is-multiline{flex-wrap:wrap}.columns.is-vcentered{align-items:center}.column{display:block;flex-basis:0;flex-grow:1;flex-shrink:1;padding:.75rem}.column.is-half-desktop{flex:none;width:50%}.column.is-half-widescreen{flex:none;width:50%}.column.is-half-fullhd{flex:none;width:50%}.column.is-half-tablet{flex:none;width:50%}.column.is-half-desktop{flex:none;width:50%}.column.is-full-tablet{flex:none;width:100%}.card{background-color:#fff;border-radius:.25rem;box-shadow:0 .5em 1em -0.125em rgba(10,10,10,.1),0 0px 0 1px rgba(10,10,10,.02);color:#4a4a4a;max-width:100%;position:relative}.card-image{display:block;position:relative}.card-image:first-child img{border-top-left-radius:.25rem;border-top-right-radius:.25rem}.de-PageWrap-subHeader .de-PageWrap-prioritySportNav{backdrop-filter:blur(3px);-webkit-backdrop-filter:blur(3px);background:transparent}.de-PageWrap-wideMenuInner{box-shadow:0 25px 25px 0px rgba(128,128,128,. ...

# %%
response.headers # Response headers (as a Python dictionary)
# Out:
# {'Date': 'Sun, 03 Mar 2024 18:49:01 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Sorting-Hat-PodId': '61', 'X-Sorting-Hat-ShopId': '13306287', 'X-Storefront-Renderer-Rendered': '1', 'Set-Cookie': 'secure_customer_sig=; path=/; expires=Mon, 03 Mar 2025 18:49:01 GMT; secure; HttpOnly; SameSite=Lax, localization=US; path=/; expires=Mon, 03 Mar 2025 18:49:01 GMT, cart_currency=USD; path=/; expires=Sun, 17 Mar 2024 18:49:01 GMT, _cmp_a=%7B%22purposes%22%3A%7B%22p%22%3Atrue%2C%22a%22%3Atrue%2C%22m%22%3Atrue%2C%22t%22%3Atrue%7D%2C%22display_banner%22%3Afalse%2C%22sale_of_data_region%22%3Afalse%7D; domain=decathlon.com; path=/; expires=Mon, 04 Mar 2024 18:49:01 GMT; SameSite=Lax, _tracking_consent=%7B%22v%22%3A%222.1%22%2C%22reg%22%3A%22GDPR%22%2C%22region%22%3A%22FRIDF%22%2C%22con%22%3A%7B%22CMP%22%3A%7B%22s%22%3A%22%22%2C%22p%22%3A%22%22%2C%22m%22%3A%22%22%2C%22a%22%3A%22%22%7D%7D%7D; Expires=Mon, 03-Mar-25 18:49:01 GMT; Domain=decathlon.com; Path=/; SameSite=Lax, _shopify_y=2ee9dd9d-a3bf-4520-b795-5de5870fa970; Expires=Mon, 03-Mar-25 18:49:01 GMT; Domain=decathlon.com; Path=/; SameSite=Lax, _shopify_s=ab4456fa-3986-47f4-b565-46580daf92f0; Expires=Sun, 03-Mar-24 19:19:01 GMT; Domain=decathlon.com; Path=/; SameSite=Lax, _orig_referrer=; Expires=Sun, 17-Mar-24 18:49:01 GMT; Domain=decathlon.com; Path=/; HttpOnly; SameSite=Lax, _landing_page=%2Fcollections%2Fmountain-bikes; Expires=Sun, 17-Mar-24 18:49:01 GMT; Domain=decathlon.com; Path=/; HttpOnly; SameSite=Lax', 'Link': '<https://cdn.shopify.com>; rel="preconnect", <https://cdn.shopify.com>; rel="preconnect"; crossorigin', 'ETag': 'W/"cacheable:3f0da7320d75391feb05aae00fdf9de1"', 'X-Cache': 'miss', 'Content-Security-Policy': 'block-all-mixed-content; frame-ancestors *; upgrade-insecure-requests;', 'Strict-Transport-Security': 'max-age=7889238', 'X-ShopId': '13306287', 'X-ShardId': '61', 'Vary': 'Accept', 'Content-Language': 'en', 'powered-by': 'Shopify', 'Server-Timing': 'processing;dur=347, db;dur=121, render;dur=150, wasm, asn;desc="12322", edge;desc="CDG", country;desc="FR", theme;desc="121925795902", pageType;desc="collection", servedBy;desc="xnvl", requestID;desc="fae44744-97ba-4c80-afc7-540626b65928-1709491740", cfRequestDuration;dur=430.999994', 'X-Shopify-Stage': 'production', 'X-Dc': 'gcp-europe-west9,gcp-europe-west1,gcp-europe-west1', 'X-Request-ID': 'fae44744-97ba-4c80-afc7-540626b65928-1709491740', 'X-Download-Options': 'noopen', 'X-XSS-Protection': '1; mode=block', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-Content-Type-Options': 'nosniff', 'CF-Cache-Status': 'DYNAMIC', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=JQHoyUJvO3ERc2hwY%2BPMyeaS0F5ogQO5%2BtqZ4DsY2va62zWX5soX5waLvi5YMKgTRvVnlKjyPFPa0UMMpIHXjPoJ90n8CjRNidExHsitP0QrSp%2BYT5lGW4RAnIEoVBarLCfH"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0.01,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '85ebcdd398ecd554-CDG', 'Content-Encoding': 'br', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
print(response.headers['Content-Type'])
# Out:
# text/html; charset=utf-8

# %% [markdown]
# When interacting with APIs, we typically receive data in JSON format. However, web scraping provides us with HTML, which can be challenging to navigate. Fortunately, Beautiful Soup simplifies this process, making our work more manageable!

# %% [markdown]
# ### Parsing HTML with Beautiful Soup
#
# To parse the HTML, we'll employ the renowned Python library, [Beautiful Soup 4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/). For a deeper understanding of its functionalities, explore the [official documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# The code above parses the HTML (stored in `response.content`) into a special object called `soup` that the Beautiful Soup library understands. In other words, Beautiful Soup is **reading the HTML and making sense of its structure.**

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())  # This formats the HTML in a readable way
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if IE 9 ]><html class="ie9 no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <!-- Title and description ============================================= -->
#   <title>
#    Mountain Bikes | Decathlon
#   </title>
#   <link href="//cdn.dynamicyield.com" rel="preconnect"/>
#   <link href="//st.dynamicyield.com" rel="preconnect"/>
#   <script async="" id="adeptmind-js" src="//www.decathlon.com/cdn/shop/t/242/assets/adept-shop-ui.js?v=161985829706692883941707861092">
#   </script>
#   <script async="" src="https://saa.wooly.com/wooly-analytics.js?token=wwjmqk1wqu9ldux4bfa5nlbqunfqzz09tBJeXPlRhn5W4aclKg0rqLGzWcz4Vo&amp;source=shopify_checkout" type="application/javascript">
#   </script>
#   <script async="" src="//www.decathlon.com/cdn/shop/t/242/assets/modernizr.min.js?v=137617515274177302221667891820">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/built-lazy-images.js?v=65193528714826927711667891934" type="module">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/jquery.min.js?v=74721525869110791951667891788" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .de-headerSection{position:sticky;top:0;z-index:1000}.de-header2-signin{display:none !important}.cd-popup{position:fixed;top:-100%}.message-slider{height:31px;text-align:center}.de-header2-right{display:flex}.de-MenuBar-label{font-size:16px}.de-header2-box{font-family:avalonbold,Helvetica Neue,Helvetica,Arial,sans-serif;border:1px solid #bababa;text-align:left;margin-right:22px;margin-top:auto;margin-bottom:auto;padding-left:6%;padding-right:4%;width:7vw;min-width:104px;height:35px;font-size:16px}.de-header2-box:hover{background-color:#ebebeb}.de-header2-box>svg{vertical-align:middle;margin-right:4%}.de-MenuBar-action>svg{position:relative;right:-2px}.de-PageWrap-subHeader>.de-PageWrap-logoImage{height:47px !important}.de-header2-right>.de-MenuBar-action{padding:0;height:47px;width:58px}.de-header2-right>.de-MenuBar-action--primary:before{transform:translateX(-320%) skewX(-10deg);left:45%}.de-header2-signin{display:none}#navigation-2_0 .de-PageWrap-menu{top:72px}.de-messageBarInner{background-color:#1f1f1f}.de-PageWrap-subHeader{justify-content:space-between}.de-PageWrap-menu{width:100%}.de-searchModal{display:none}.columns.is-mobile>.column.is-full{flex:none;width:100%}.columns.is-mobile>.column.is-three-quarters{flex:none;width:75%}.columns{margin-left:-0.75rem;margin-right:-0.75rem;margin-top:-0.75rem}.columns:last-child{margin-bottom:-0.75rem}.columns:not(:last-child){margin-bottom:calc(1.5rem - 0.75rem)}.columns.is-centered{justify-content:center}.columns.is-gapless{margin-left:0;margin-right:0;margin-top:0}.columns.is-gapless>.column{margin:0;padding:0 !important}.columns.is-gapless:last-child{margin-bottom:0}.columns.is-mobile{display:flex}.columns.is-multiline{flex-wrap:wrap}.columns.is-vcentered{align-items:center}.column{display:block;flex-basis:0;flex-grow:1;flex-shrink:1;padding:.75rem}.column.is-half-desktop{flex:none;width:50%}.column.is-half-widescreen{flex:none;width:50%}.column.is-half-fullhd{flex:none;width:50%}.column.is-half-tablet{flex:none;width:50%}.column.is-half-desktop{flex:none;width:50%}.column.is-full-tablet{flex:none;width:100%}.card{background-color:#fff;border-radius:.25rem;box-shadow:0 .5em 1em -0.125em rgba(10,10,10,.1),0 0px 0 1px rgba(10,10,10,.02);color:#4a4a4a;max-width:100%;position:relative}.card-image{display:block;position:relative}.card-image:first-child img{border-top-left-radius:.25rem;border-top-right-radius:.25rem}.de-PageWrap-subHeader .de-PageWrap-prioritySportNav{backdrop-filter:blur(3px);-webkit-backdrop-filter:blur(3px);background:transparent}.de-PageWrap-wideMenuInner{box-shadow:0 25px 25px 0px rgba(128,128,128,.1)}.de-headerMessageBarContainer{background-color:#1f1f1f}.message-slide a,.message-slide a:hover,.message-slide a:focus{color:#fff}.message-slide span{padding-right:12px}.message-slide1,.message-slide2,.message-slide3{position:absolute;width:100%;height:auto}.cd-popup-container .section3{justify-content:center}.message-link .de-messageBar-title{font-family:"avalonregular","HelveticaNeue","Helvetica Neue",Helvetica,Arial,sans-serif;font-style:normal;font-weight:400;font-size:12px;line-height:16.8px;text-decoration:underline;padding-top:8px;color:#fff}.message-link .de-messageBar-title:hover,.message-link .de-messageBar-title:focus{color:#11afff}.column.section3{padding-top:.375rem !important;padding-right:.375rem !important;padding-bottom:12px !important;padding-left:.375rem !important;margin-left:0 !important;margin-right:0 !important}.card.section3{box-shadow:none !important}.message-slide1{animation:fade 14s infinite;-webkit-animation:fade 14s infinite}.message-slide2{animation:fade2 14s infinite;-webkit-animation:fade2 14s infinite}.message-slide3{animation:fade3 14s infinite;-webkit-animation:fade3 14s infinite}.de-hide-me{z-index:0 !important;cursor:none;visibility:hidden}.skip-to-content:focus{text-decoration:underline;text-decoration-color:#007dbc;outline:2px solid #cbfb00}.de-SignInLink:focus .de-MenuBar-label{text-decoration:underline}.de-StickyMenuItem: ...
#   </style>
#   <style type="text/css">
#    .de-SwatchObjects-item{display:flex;flex-basis:88px;margin-bottom:8px;margin-right:8px;min-width:72px;overflow:hidden;position:relative}@supports(display: grid){.de-SwatchObjects-item{margin:0}}.de-SwatchObjects--productTile .de-SwatchObjects-item{align-items:center;border:1.5px solid #fff;border-radius:50%;display:flex;flex-basis:auto;height:32px;justify-content:center;min-width:32px;padding:.3em;position:relative;width:32px}@media(min-width: 40em){.de-SwatchObjects--productTile .de-SwatchObjects-item{height:42px;min-width:42px;padding:.4em;width:42px}}@media(min-width: 1080px){.de-SwatchObjects--productTile .de-SwatchObjects-item{height:48px;min-width:48px;padding:.5em;width:48px}}.de-SwatchObjects--productTile .de-SwatchObjects-item:after{border-radius:50%;box-shadow:inset 0 0 0 2px #fff;content:"";height:100%;left:0;position:absolute;top:0;width:100%;z-index:600}.de-SwatchObjects--productTile .de-SwatchObject-image{-webkit-transform:scale(1.32);-webkit-transform-origin:center center;transform:scale(1.32);transform-origin:center center}.de-Button{background-color:#007dbc;border:2px solid #007dbc;color:#fff}.de-CSRWidget-Target{height:36vw;min-height:425px;max-height:600px}.de-ProductFlag{background-color:#fff;border-width:2px;border-style:solid;border-color:#2a2b2c;border-radius:.5em;display:inline-block;line-height:1.2;margin:0 0 0 .25em;padding:.2em .6em;text-align:center;text-transform:uppercase;z-index:1}@media(min-width: 40em){.de-ProductFlag{padding:.38125em .75375em}}.de-ProductFlag--primary{color:#007dbc;border-color:#007dbc}.de-ProductFlag--secondary{color:#fff;border-color:#e53322;background-color:#e53322}.de-ProductFlag--tertiary{color:#2a2b2c;background-color:#cbfb00;border-color:#cbfb00}.de-ProductFlag--blackfriday,.de-ProductFlag--cybermonday,.de-ProductFlag--newdeal{color:#fff;background-color:#e53322;border-color:#e53322}.de-ProductFlag--sale{color:#e53322;border-color:#e53322}.de-ProductFlag--ecogreen{color:#fff;background-color:#4d6f56;border-color:#4d6f56}.de-ProductTile{margin:0 .5em;padding:.5em 0;width:100%}@media(min-width: 40em){.de-ProductTile{margin:0 .5625rem;padding:.5625rem 0}}.de-ProductTile-showcase{background-color:#fff;text-align:center;position:relative}.de-ProductTile-showcase .de-ProductFlag{left:0;right:auto}.de-productTile-showcaseImageContainer{height:0;overflow:hidden;padding-top:100%;position:relative}.de-ProductTile-showcaseImage{left:50%;max-height:100%;position:absolute;top:0;transform:translate(-50%)}.de-ProductTile-flagContainer{left:.15em;position:absolute;top:.4em;z-index:1}.de-ProductTileCarousel{-webkit-overflow-scrolling:touch;display:flex;overflow-x:auto;position:relative}@media(min-width: 40em){.de-ProductTileCarousel{left:initial;margin-left:0;margin-right:0;right:initial;width:100%}}@media(min-width: 40em){.de-ProductTileCarousel{padding:25px 40px}}@media(min-width: 60em){.de-ProductTileCarousel{padding:25px 50px}}@media(min-width: 320px){.de-ProductTileCarousel-item{flex:1 0 47vw}}@media(min-width: 375px){.de-ProductTileCarousel-item{flex:1 0 41vw}}@media(min-width: 945px){.de-ProductTileCarousel-item{flex:1 0 50%}}@media(min-width: 1149px){.de-ProductTileCarousel-item{flex:1 0 33.33%}}@media(min-width: 1372px){.de-ProductTileCarousel-item{flex:1 0 25%}}@media(min-width: 1679px){.de-ProductTileCarousel-item{flex:1 0 20%}}*,:after,:before,input{box-sizing:border-box}html{overflow-y:scroll}body,html{padding:0;margin:0}article,footer,header,main,nav,section{display:block}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}.grid--full:after,.grid-uniform:after{content:"";display:table;clear:both}img[loading=lazy]:not([src]){visibility:hidden}.grid--full,.grid-uniform{list-style:none;padding:0;margin:0 0 0 -15px}@media screen and (min-width: 480px){.grid--full,.grid-uniform{margin-left:-30px}}.grid__item{box-sizing:border-box;float:left;min-height:1px;padding-left:30px;vertical-align:top;width:100%}.grid- ...
#   </style>
#   <style id="adeptmind-css">
#    .template-search main{opacity: 0; pointer-events:none}
#   </style>
#   <!-- Preload web fonts ================================================== -->
#   <link as="font" crossorigin="anonymous" href="//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Bold-webfont.woff2?v=13987910295491874761667891283" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Book-webfont.woff2?v=45737076064894658321667891286" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Demi-webfont.woff2?v=70268478816191370301667891289" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Medium-webfont.woff2?v=104411186118392655941667891292" rel="preload" type="font/woff2"/>
#   <style>
#    @font-face {
#       font-family: 'avalon_mediumbold';
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Bold-webfont.eot?v=78597785429813193191667891280);
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Bold-webfont.eot?%23iefix&v=78597785429813193191667891280) format('embedded-opentype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Bold-webfont.woff2?v=13987910295491874761667891283) format('woff2'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Bold-webfont.woff?v=113951836532318800641667891282) format('woff'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Bold-webfont.ttf?v=2814839166618404711667891282) format('truetype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Bold-webfont.svg%23avalon_mediumbold?143983) format('svg');
#       font-weight: normal;
#       font-style: normal;
#   	font-display: swap;
#   }
#
#   @font-face {
#       font-family: 'avalonregular';
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Book-webfont.eot?v=81862561962025572731667891283);
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Book-webfont.eot?%23iefix&v=81862561962025572731667891283) format('embedded-opentype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Book-webfont.woff2?v=45737076064894658321667891286) format('woff2'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Book-webfont.woff?v=165903215869188773081667891285) format('woff'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Book-webfont.ttf?v=166975206091216758681667891284) format('truetype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Book-webfont.svg%23avalonregular?143983) format('svg');
#       font-weight: normal;
#       font-style: normal;
#   	font-display: swap;
#   }
#
#   @font-face {
#       font-family: 'avalonbold';
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Demi-webfont.eot?v=129644579174542231361667891286);
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Demi-webfont.eot?%23iefix&v=129644579174542231361667891286) format('embedded-opentype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Demi-webfont.woff2?v=70268478816191370301667891289) format('woff2'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Demi-webfont.woff?v=17677358014615553361667891288) format('woff'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Demi-webfont.ttf?v=84860554161213060081667891288) format('truetype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Demi-webfont.svg%23avalonbold?143983) format('svg');
#       font-weight: normal;
#       font-style: normal;
#   	font-display: swap;
#   }
#
#   @font-face {
#       font-family: 'avalonmedium';
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Medium-webfont.eot?v=101713962460368477191667891289);
#       src: url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Medium-webfont.eot?%23iefix&v=101713962460368477191667891289) format('embedded-opentype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Medium-webfont.woff2?v=104411186118392655941667891292) format('woff2'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Medium-webfont.woff?v=171608890807765242741667891291) format('woff'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Medium-webfont.ttf?v=58284677999347643491667891291) format('truetype'),
#            url(//www.decathlon.com/cdn/shop/t/242/assets/Avalon-Medium-webfont.svg%23avalonmedium?143983) format('svg');
#       font-weight: normal;
#       font-style: normal;
#   	font-display: swap;
#   }
#   </style>
#   <script defer="" src="//www.decathlon.com/cdn/shop/t/242/assets/built-header.js?v=2673137394177307831709240080" type="module">
#   </script>
#   <script defer="" src="//static.klaviyo.com/onsite/js/klaviyo.js?company_id=TEJqNp" type="text/javascript">
#   </script>
#   <script defer="" src="//www.decathlon.com/cdn/shop/t/242/assets/built-gorgias.js?v=23030576605451082111705607113" type="module">
#   </script>
#   <link href="https://cdn.shopify.com" rel="dns-prefetch"/>
#   <link href="//cdn.dynamicyield.com" rel="dns-prefetch"/>
#   <link href="//st.dynamicyield.com" rel="dns-prefetch"/>
#   <meta content="Efficient. Lightweight. Precise. Decathlon mountain bikes are made with shock absorption to adapt to you and your terrain. We design for any sport in any weather by consulting professionals and beginners alike. Unbeatable prices." name="description"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W6S94V');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Qr redirect ================================================== -->
#   <!-- Basic page needs ================================================== -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="//www.decathlon.com/cdn/shop/t/242/assets/apple-touch-icon.png?v=103541567537437490291667891279" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="//www.decathlon.com/cdn/shop/t/242/assets/favicon-32x32.png?v=48199063949251108661667891739" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="//www.decathlon.com/cdn/shop/t/242/assets/favicon-16x16.png?v=41005602088648927241667891738" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="//www.decathlon.com/cdn/shop/t/242/assets/site.webmanifest?v=24728881619569108341667891855" rel="manifest"/>
#   <link color="#0080c4" href="//www.decathlon.com/cdn/shop/t/242/assets/safari-pinned-tab.svg?v=65785397592979389621667891834" rel="mask-icon"/>
#   <link href="https://www.decathlon.com/collections/mountain-bikes" hreflang="en-us" rel="alternate"/>
#   <meta content="Decathlon" name="apple-mobile-web-app-title"/>
#   <meta content="Decathlon" name="application-name"/>
#   <meta content="#0080c4" name="msapplication-TileColor"/>
#   <meta content="#f3f3f3" name="theme-color"/>
#   <!-- Helpers ================================================== -->
#   <!-- /snippets/social-meta-tags.liquid -->
#   <meta content="website" property="og:type"/>
#   <meta content="Mountain Bikes" property="og:title"/>
#   <meta content="http://www.decathlon.com/cdn/shop/t/242/assets/logo.png?v=118260531780585138971667891792" property="og:image"/>
#   <meta content="https://www.decathlon.com/cdn/shop/t/242/assets/logo.png?v=118260531780585138971667891792" property="og:image:secure_url"/>
#   <meta content="https://www.decathlon.com/collections/mountain-bikes" property="og:url"/>
#   <meta content="Decathlon" property="og:site_name"/>
#   <meta content="@DecathlonUSA" name="twitter:site"/>
#   <meta content="summary" name="twitter:card"/>
#   <link href="https://www.decathlon.com/collections/mountain-bikes" rel="canonical"/>
#   <meta content="width=device-width,initial-scale=1,shrink-to-fit=no" name="viewport"/>
#   <meta content="#f3f3f3" name="theme-color"/>
#   <link as="style" href="//www.decathlon.com/cdn/shop/t/242/assets/slick.css?v=179661253729407977801667891856" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#   <link as="style" href="//www.decathlon.com/cdn/shop/t/242/assets/slick-theme.css?v=33918400535307118041696451689" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#   <link href="//www.decathlon.com/cdn/shop/t/242/assets/patterns-toolkit.css?v=64916195638649419181709240256" media="all" rel="stylesheet" type="text/css">
#    <link as="style" href="//www.decathlon.com/cdn/shop/t/242/assets/built-collection-page.css?v=108027132111932066941698336139" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#    <link href="//www.decathlon.com/cdn/shop/t/242/assets/legacySupport.css?v=25901130414653851091667891791" media="all" rel="stylesheet" type="text/css">
#     <link href="//www.decathlon.com/cdn/shop/t/242/assets/cadence.css?v=66365134489107520741671752065" media="all" rel="stylesheet" type="text/css">
#      <link href="//www.decathlon.com/cdn/shop/t/242/assets/icomoon.css?v=169023608298310693741696451689" media="all" rel="stylesheet" type="text/css">
#       <link as="style" href="//www.decathlon.com/cdn/shop/t/242/assets/built-product-tile.css?v=85466660746932268651701382882" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#       <link href="//www.decathlon.com/cdn/shop/t/242/assets/built-account.css?v=88798091896128262611696451685" media="all" rel="stylesheet" type="text/css">
#        <link as="style" href="//www.decathlon.com/cdn/shop/t/242/assets/built-compositions-decathlon-difference.css?v=82881184543681734671667891362" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#        <link as="style" href="//www.decathlon.com/cdn/shop/t/242/assets/built-general.css?v=125548801122937381851709240068" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#        <!-- Header hook for plugins ================================================== -->
#        <script>
#         window.performance && window.performance.mark && window.performance.mark('shopify.content_for_header.start');
#        </script>
#        <meta content="rboyricxnkf6vwcz97v7s3ugv7antw" name="facebook-domain-verification"/>
#        <meta content="/13306287/digital_wallets/dialog" id="shopify-digital-wallet" name="shopify-digital-wallet"/>
#        <meta content="9cb3ae2eead1376cead48f51504e8535" name="shopify-checkout-api-token"/>
#        <meta data-currency="USD" data-environment="production" data-locale="en_US" data-paypal-v4="true" data-shop-id="13306287" data-venmo-supported="true" id="in-context-paypal-metadata"/>
#        <link href="/collections/mountain-bikes.atom" rel="alternate" title="Feed" type="application/atom+xml">
#         <link href="https://www.decathlon.com/collections/mountain-bikes.oembed" rel="alternate" type="application/json+oembed"/>
#         <script async="async" src="/checkouts/internal/preloads.js?locale=en-US">
#         </script>
#         <script async="async" crossorigin="anonymous" src="https://shop.app/checkouts/internal/preloads.js?locale=en-US&amp;shop_id=13306287">
#         </script>
#         <script id="apple-pay-shop-capabilities" type="application/json">
#          {"shopId":13306287,"countryCode":"US","currencyCode":"USD","merchantCapabilities":["supports3DS"],"merchantId":"gid:\/\/shopify\/Shop\/13306287","merchantName":"Decathlon","requiredBillingContactFields":["postalAddress","email","phone"],"requiredShippingContactFields":["postalAddress","email","phone"],"shippingType":"shipping","supportedNetworks":["visa","masterCard","amex","discover","elo","jcb"],"total":{"type":"pending","label":"Decathlon","amount":"1.00"},"shopifyPaymentsEnabled":true,"supportsSubscriptions":true}
#         </script>
#         <script id="shopify-features" type="application/json">
#          {"accessToken":"9cb3ae2eead1376cead48f51504e8535","betas":["rich-media-storefront-analytics"],"domain":"www.decathlon.com","predictiveSearch":true,"shopId":13306287,"smart_payment_buttons_url":"https:\/\/www.decathlon.com\/cdn\/shopifycloud\/payment-sheet\/assets\/latest\/spb.en.js","dynamic_checkout_cart_url":"https:\/\/www.decathlon.com\/cdn\/shopifycloud\/payment-sheet\/assets\/latest\/dynamic-checkout-cart.en.js","dynamic_checkout_cart_button_sizes":{"maxWidth":500,"minWidth":140},"locale":"en","flg4ff40b22":false}
#         </script>
#         <script>
#          var Shopify = Shopify || {};
# Shopify.shop = "decathlon-usa.myshopify.com";
# Shopify.locale = "en";
# Shopify.currency = {"active":"USD","rate":"1.0"};
# Shopify.country = "US";
# Shopify.theme = {"name":"New Master\/Live","id":121925795902,"theme_store_id":null,"role":"main"};
# Shopify.theme.handle = "null";
# Shopify.theme.style = {"id":null,"handle":null};
# Shopify.cdnHost = "www.decathlon.com/cdn";
# Shopify.routes = Shopify.routes || {};
# Shopify.routes.root = "/";
#         </script>
#         <script type="module">
#          !function(o){(o.Shopify=o.Shopify||{}).modules=!0}(window);
#         </script>
#         <script>
#          !function(o){function n(){var o=[];function n(){o.push(Array.prototype.slice.apply(arguments))}return n.q=o,n}var t=o.Shopify=o.Shopify||{};t.loadFeatures=n(),t.autoloadFeatures=n()}(window);
#         </script>
#         <script>
#          window.ShopifyPay = window.ShopifyPay || {};
# window.ShopifyPay.apiHost = "shop.app\/pay";
#         </script>
#         <script>
#          window.Shopify = window.Shopify || {};
#   if (!window.Shopify.featureAssets) window.Shopify.featureAssets = {};
#   window.Shopify.featureAssets['shop-js'] = {"pay-button":["modules/client.pay-button_4a34cbc0.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"init-shop-email-lookup-coordinator":["modules/client.init-shop-email-lookup-coordinator_df8cc5e8.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"init-shop-user-avatar":["modules/client.init-shop-user-avatar_bcd8d2b0.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"init-customer-accounts-sign-up":["modules/client.init-customer-accounts-sign-up_a4b37cbd.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"init-customer-accounts":["modules/client.init-customer-accounts_2ed3ed64.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"init-shop-for-new-customer-accounts":["modules/client.init-shop-for-new-customer-accounts_1588d262.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"shop-pay-payment-request":["modules/client.shop-pay-payment-request_17b677bc.en.esm.js","modules/chunk.common_33a0a24f.esm.js","modules/chunk.shop-pay_fc4a8b96.esm.js"],"login-button":["modules/client.login-button_4223d83d.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"discount-app":["modules/client.discount-app_142a25ac.en.esm.js","modules/chunk.common_33a0a24f.esm.js"],"payment-terms":["modules/client.payment-terms_3d43cdb7.en.esm.js","modules/chunk.common_33a0a24f.esm.js"]};
#         </script>
#         <script>
#          (function() {
#   function asyncLoad() {
#     var urls = ["https:\/\/cdn.gethypervisual.com\/assets\/hypervisual.js?shop=decathlon-usa.myshopify.com","https:\/\/assets.pixlee.com\/shopify\/pixlee.shopify.v2.prod.js?shop=decathlon-usa.myshopify.com","https:\/\/analytics.getshogun.com\/collector.js?shop=decathlon-usa.myshopify.com","https:\/\/static.klaviyo.com\/onsite\/js\/klaviyo.js?company_id=TEJqNp\u0026shop=decathlon-usa.myshopify.com","https:\/\/static.klaviyo.com\/onsite\/js\/klaviyo.js?company_id=Uz9CmY\u0026shop=decathlon-usa.myshopify.com","https:\/\/static.klaviyo.com\/onsite\/js\/klaviyo.js?company_id=Uz9CmY\u0026shop=decathlon-usa.myshopify.com","https:\/\/static.returngo.ai\/master.returngo.ai\/returngo.min.js?shop=decathlon-usa.myshopify.com","https:\/\/config.gorgias.chat\/bundle-loader\/01GYCBSN7PHYA9DS6ASWZGWX22?source=shopify1click\u0026shop=decathlon-usa.myshopify.com","\/\/cdn.shopify.com\/proxy\/3a044f82747821f2a6618c9f5c44c9c089205a250d0bf86daa03a80a9483480e\/sa.getroster.com\/sa.js?token=wwjmqk1wqu9ldux4bfa5nlbqunfqzz09tBJeXPlRhn5W4aclKg0rqLGzWcz4Vo\u0026shop=decathlon-usa.myshopify.com\u0026sp-cache-control=cHVibGljLCBtYXgtYWdlPTkwMA","https:\/\/sca-cdn.dynamic-yield.com\/scripts\/dynamic-yield.js?shop=decathlon-usa.myshopify.com","https:\/\/size-guides.esc-apps-cdn.com\/1704838754-app.decathlon-usa.myshopify.com.js?shop=decathlon-usa.myshopify.com","\/\/app.backinstock.org\/widget\/11152_1706696324.js?category=bis\u0026v=6\u0026shop=decathlon-usa.myshopify.com","https:\/\/bundle.dyn-rev.app\/loader.js?g_cvt_id=a110def0-d58e-4319-a849-6fd60afa15fe\u0026shop=decathlon-usa.myshopify.com"];
#     for (var i = 0; i < urls.length; i++) {
#       var s = document.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.src = urls[i];
#       var x = document.getElementsByTagName('script')[0];
#       x.parentNode.insertBefore(s, x);
#     }
#   };
#   if(window.attachEvent) {
#     window.attachEvent('onload', asyncLoad);
#   } else {
#     window.addEventListener('load', asyncLoad, false);
#   }
# })();
#         </script>
#         <script id="__st">
#          var __st={"a":13306287,"offset":-28800,"reqid":"fae44744-97ba-4c80-afc7-540626b65928-1709491740","pageurl":"www.decathlon.com\/collections\/mountain-bikes","u":"4f9870ce398e","p":"collection","rtyp":"collection","rid":1915387917};
#         </script>
#         <script>
#          window.ShopifyPaypalV4VisibilityTracking = true;
#         </script>
#         <script>
#          !function(o){o.addEventListener("DOMContentLoaded",function(){window.Shopify=window.Shopify||{},window.Shopify.recaptchaV3=window.Shopify.recaptchaV3||{siteKey:"6LeHG2ApAAAAAO4rPaDW-qVpPKPOBfjbCpzJB9ey"};var t=['form[action*="/contact"] input[name="form_type"][value="contact"]','form[action*="/comments"] input[name="form_type"][value="new_comment"]','form[action*="/account"] input[name="form_type"][value="customer_login"]','form[action*="/account"] input[name="form_type"][value="recover_customer_password"]','form[action*="/account"] input[name="form_type"][value="create_customer"]','form[action*="/contact"] input[name="form_type"][value="customer"]'].join(",");function n(e){e=e.target;null==e||null!=(e=function e(t,n){if(null==t.parentElement)return null;if("FORM"!=t.parentElement.tagName)return e(t.parentElement,n);for(var o=t.parentElement.action,r=0;r<n.length;r++)if(-1!==o.indexOf(n[r]))return t.parentElement;return null}(e,["/contact","/comments","/account"]))&&null!=e.querySelector(t)&&((e=o.createElement("script")).setAttribute("src","https://cdn.shopify.com/shopifycloud/storefront-recaptcha-v3/v0.6/index.js"),o.body.appendChild(e),o.removeEventListener("focus",n,!0),o.removeEventListener("change",n,!0),o.removeEventListener("click",n,!0))}o.addEventListener("click",n,!0),o.addEventListener("change",n,!0),o.addEventListener("focus",n,!0)})}(document);
#         </script>
#         <script crossorigin="anonymous" data-source-attribution="shopify.loadfeatures" defer="defer" integrity="sha256-h4dvokWvGcvRSqiG7VnGqoonxF0k3NeoHPLSMjUGIz4=" src="//www.decathlon.com/cdn/shopifycloud/shopify/assets/storefront/load_feature-87876fa245af19cbd14aa886ed59c6aa8a27c45d24dcd7a81cf2d2323506233e.js">
#         </script>
#         <script crossorigin="anonymous" defer="defer" src="//www.decathlon.com/cdn/shopifycloud/shopify/assets/shopify_pay/storefront-a2d444786d996da5634fbbaeeffe6104ee672440dfa6cdcaebfb27dceaaf9c0f.js?v=20220906">
#         </script>
#         <script crossorigin="anonymous" data-source-attribution="shopify.dynamic-checkout" defer="defer" integrity="sha256-HAs5a9TQVLlKuuHrahvWuke+s1UlxXohfHeoYv8G2D8=" src="//www.decathlon.com/cdn/shopifycloud/shopify/assets/storefront/features-1c0b396bd4d054b94abae1eb6a1bd6ba47beb35525c57a217c77a862ff06d83f.js">
#         </script>
#         <style id="shopify-dynamic-checkout-cart">
#          @media screen and (min-width: 750px) {
#   #dynamic-checkout-cart {
#     min-height: 50px;
#   }
# }
#
# @media screen and (max-width: 750px) {
#   #dynamic-checkout-cart {
#     min-height: 240px;
#   }
# }
#         </style>
#         <script>
#          window.performance && window.performance.mark && window.performance.mark('shopify.content_for_header.end');
#         </script>
#         <script>
#          // Create a global Decathlon object to hold values needed throughout
#   window.DEC_GLOBALS = window.DEC_GLOBALS || {};
#   DEC_GLOBALS.moneyFormat = "${{amount}}";
#   DEC_GLOBALS.isAllShippingFree = false;
#   DEC_GLOBALS.freeShippingThreshold = 4900;
#   DEC_GLOBALS.productTileSuccessMessageTimeout = 5000
#   DEC_GLOBALS.productTileFailureMessageTimeout = 5000
#   DEC_GLOBALS.template = "collection";
#   DEC_GLOBALS.storePickupRadius = 15;
#   DEC_GLOBALS.mapMarkerActive = '//www.decathlon.com/cdn/shop/t/242/assets/map-marker-active.png?v=84512222113018069621667891819'
#   DEC_GLOBALS.mapMarkerInactive = '//www.decathlon.com/cdn/shop/t/242/assets/map-marker-inactive.png?v=133352752267223424851667891820'
#         </script>
#         <!-- /snippets/oldIE-js.liquid -->
#         <!--[if lt IE 9]>
# <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.2/html5shiv.min.js" type="text/javascript"></script>
# <script src="//www.decathlon.com/cdn/shop/t/242/assets/respond.min.js?v=52248677837542619231667891833" type="text/javascript"></script>
# <link href="//www.decathlon.com/cdn/shop/t/242/assets/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
# <link href="//www.decathlon.com/search?q=a881589ce478f52afc5c2ad022a10418" id="respond-redirect" rel="respond-redirect" />
# <script src="//www.decathlon.com/search?q=a881589ce478f52afc5c2ad022a10418" type="text/javascript"></script>
# <![endif]-->
#         <script src="//www.decathlon.com/cdn/shop/t/242/assets/appmate.js?v=140505979180690333871667891279" type="text/javascript">
#         </script>
#         <script type="text/javascript">
#          ;(function(){
#   if (typeof Appmate === 'undefined') return; // In case lib didn't load.
#
#   Appmate.init({
#     shop: {
#       domain: 'www.decathlon.com'
#    },
#     session: {
#       customer: ''
#     },
#     globals: {
#       settings: {
#         app_wk_icon: 'heart',
#         app_wk_share_position: 'hidden',
#         app_wk_products_per_row: 4
#       },
#       customer: '',
#       customer_accounts_enabled: true,
#     },
#     wishlist: {
#       loginRequired: false,
#       handle: "/pages/wishlist",
#       proxyHandle: "/a/wk",
#       share: {
#         handle: "/pages/shared-wishlist",
#         title: 'My Wishlist',
#         description: 'Check out some of my favourite things @ Decathlon.',
#         imageTitle: 'Decathlon',
#         hashTags: 'wishlist',
#         twitterUser: false // will be used with via
#       }
#     }
#   });
#
# })();
#         </script>
#         <script type="text/javascript">
#          ;(function(){
#   if (typeof Appmate === 'undefined') return; // In case lib didn't load.
#
#   Appmate.wk.on({
#     'click [data-wk-add-product]': eventHandler(function(){
#       var product = this.getAttribute('data-wk-add-product');
#
#       var variant = $(this).parents('.timber-activeProduct').find('.product-single__variants').val();
#       if ($('body').hasClass('template-product')) {
#         var variant = window.currentVariant.id;
#       }
#
#       if (Appmate.wk.collection.containsProduct(product)) {
#         return;
#       }
#
#       Appmate.wk.addProduct(product, variant);
#
#       if (!window.addToWishlist) {
#         window.decathlon.addPromo('<p class="u-marginBottom0x"><a href="/pages/wishlist" class="u-textUppercase">Product added. View your wishlist</a></p>', 'js-wishlistBanner');
#       } else {
#               $('js-wishlistBanner').remove();
#       //window.decathlon.addPromo('<p class="u-marginBottom0x"><a href="/pages/wishlist" class="u-textUppercase">Product added! View your wishlist</a></p>', 'js-wishlistBanner');
#
#       var itemPopupTemplate = Handlebars.compile($('#AddedItemTemplate').html());
#
#       if ($('body').hasClass('template-product')) {
#         var productSlug = window.location.pathname;
#       } else {
#         var productSlug = $(this).parents('.timber-activeProduct').find('.collectionProduct-title').attr('href');
#       }
#
#       $.get(productSlug +'.json', function(res, status, data) {
#         var context = data.responseJSON.product;
#         for (var i = 0; i < context.variants.length; i++) {
#           if (context.variants[i].id == parseInt(variant)) {
#             context.variant_options = context.variants[i].title;
#             context.price = context.variants[i].price;
#             context.image = context.variants[i].image_id;
#           }
#         }
#         for (var i = 0; i < context.images.length; i++) {
#           if (context.images[i].id == context.image) {
#             context.image = context.images[i].src;
#           }
#         }
#         context.product_title = context.title;
#         if (context.variant_options) {
#           context.variant_options = context.variant_options.split(' / ');
#         } else {
#           context.variant_options = context.variants[0].title.split(' / ');
#         }
#
#         context.isWishlist = true;
#
#         /* set the add to cart pane to load once the thumbnail loads */
#         var thumbnail = new Image();
#
#         /* display the item popup and setup some event listeners */
#         function displayItemPopup() {
#           $('#AddedItemPopup').remove();
#           $('body').append(itemPopupTemplate(context));
#
#           $('#AddedItemPopup .close-itemPopup-btn').click(function(e) {
#             $('#AddedItemPopup').remove();
#           });
#
#           $('#AddedItemPopup .js-submitCart').click(function(e) {
#             e.preventDefault();
#             $('.cart__checkout').click();
#           });
#
#           setTimeout(function() {
#             $('#AddedItemPopup').remove();
#           }, 3000);
#         }
#         thumbnail.onload = displayItemPopup;
#
#         if ($('.productRating').length > 0) {
#           context.rating = $('.productRating').html();
#         } else {
#           context.rating = $('.collectionProduct[data-product-id="'+ context.id +'"] .starRating').html();
#         }
#         context.price_dollars = Shopify.formatMoney(context.price, "${{amount}}");
#         context.subtotal = $('#CartSubtotal').text();
#         var defaultTitleIndex = context.variant_options.indexOf('Default Title');
#         if (defaultTitleIndex > -1) {
#           context.variant_options.splice(defaultTitleIndex, 1);
#         }
#
#         /* if subtotal is empty then the cart needs to be loaded */
#         if (!context.subtotal) {
#           function getCartHandler(e, cart) {
#             $('body').off('afterGetCart.ajaxCart', getCartHandler);
#             context.subtotal = Shopify.formatMoney(cart.total_price, "${{amount}}");
#             thumbnail.src = context.image;
#           }
#           $('body').on('afterGetCart.ajaxCart', getCartHandler);
#           ajaxCart.load();
#
#         } else {
#           thumbnail.src = context.image;
#         }
#       });
#
#
#         if ($('body').hasClass('template-product') && window.addToWishlist) {
#           $('.addToCartText').text('Remove from wishlist');
#         }
#       }
#
#     }),
#     'click [data-wk-remove-product]': eventHandler(function(){
#       var product = this.getAttribute('data-wk-remove-product');
#       Appmate.wk.removeProduct(product);
#
#       $('js-wishlistBanner').remove();
#       window.decathlon.addPromo('<p class="u-marginBottom0x"><a href="/pages/wishlist" class="u-textUppercase">Product removed. View your wishlist</a></p>', 'js-wishlistBanner');
#
#       if ($('body').hasClass('template-product') && window.addToWishlist) {
#         $('.addToCartText').text('Add to wishlist');
#       }
#
#
#     }),
#     'click [data-wk-remove-item]': eventHandler(function(){
#       var item = this.getAttribute('data-wk-remove-item');
#       fadeOrNot($(this), function() {
#         Appmate.wk.removeItem(item);
#       });
#     }),
#     'click [data-wk-clear-wishlist]': eventHandler(function(){
#       var wishlist = this.getAttribute('data-wk-clear-wishlist');
#       Appmate.wk.clear(wishlist);
#     }),
#     'click [data-wk-share]': eventHandler(function(){
#       var wishlist = this.getAttribute('data-wk-share');
#       var service = this.getAttribute('data-wk-share-service');
#       var shareUrl = Appmate.wk.createShareUrl(wishlist, service);
#       window.open(
#         shareUrl,
#         'wishlist_share',
#         'height=590, width=770, toolbar=no, menubar=no, scrollbars=no, resizable=no, location=no, directories=no, status=no'
#       );
#     }),
#     'click [data-wk-move-to-cart]': eventHandler(function(){
#       var $elem = $(this);
#       $form = $elem.parents('form');
#       $elem.prop("disabled", true);
#
#       var item = this.getAttribute('data-wk-move-to-cart');
#       var formData = $form.serialize();
#
#       fadeOrNot($elem, function(){
#         Appmate.wk
#         .moveToCart(item, formData)
#         .then(function(){
#           window.scrollTo(0, 0);
#           location.reload();
#           $elem.prop("disabled", false);
#         });
#       });
#     }),
#     'render .wk-option-select': function(elem){
#       appmateOptionSelect(elem);
#
#     },
#     'login-required': function () {
#       window.location = '/account/login'
#     }
#   });
#
#   function eventHandler (callback) {
#     return function (event) {
#       if (typeof callback === 'function') {
#         callback.call(this, event)
#       }
#       if (event) {
#         event.preventDefault();
#         event.stopPropagation();
#       }
#     }
#   }
#
#   function fadeOrNot($elem, callback){
#     if ($elem.parents('.wk-fadeout').length) {
#       $elem.parents('.wk-fadeout').fadeOut(callback);
#     } else {
#       callback();
#     }
#   }
# })();
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-icon-filled" type="text/x-template">
#          {% if settings.app_wk_icon == "heart" %}
#   <svg version='1.1' xmlns='http://www.w3.org/2000/svg' width='64' height='64' viewBox='0 0 64 64'>
#     <path d='M47.199 4c-6.727 0-12.516 5.472-15.198 11.188-2.684-5.715-8.474-11.188-15.201-11.188-9.274 0-16.8 7.527-16.8 16.802 0 18.865 19.031 23.812 32.001 42.464 12.26-18.536 31.999-24.2 31.999-42.464 0-9.274-7.527-16.802-16.801-16.802z' fill='#000'></path>
#   </svg>
# {% elsif settings.app_wk_icon == "star" %}
#   <svg version='1.1' xmlns='http://www.w3.org/2000/svg' width='64' height='60.9' viewBox='0 0 64 64'>
#     <path d='M63.92,23.25a1.5,1.5,0,0,0-1.39-1H40.3L33.39,1.08A1.5,1.5,0,0,0,32,0h0a1.49,1.49,0,0,0-1.39,1L23.7,22.22H1.47a1.49,1.49,0,0,0-1.39,1A1.39,1.39,0,0,0,.6,24.85l18,13L11.65,59a1.39,1.39,0,0,0,.51,1.61,1.47,1.47,0,0,0,.88.3,1.29,1.29,0,0,0,.88-0.3l18-13.08L50,60.68a1.55,1.55,0,0,0,1.76,0,1.39,1.39,0,0,0,.51-1.61l-6.9-21.14,18-13A1.45,1.45,0,0,0,63.92,23.25Z' fill='#be8508'></path>
#   </svg>
# {% endif %}
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-icon-empty" type="text/x-template">
#          {% if settings.app_wk_icon == "heart" %}
#   <svg version='1.1' xmlns='http://www.w3.org/2000/svg' width='64px' height='60.833px' viewBox='0 0 64 60.833'>
#     <path stroke='#000' stroke-width='5' stroke-miterlimit='10' fill-opacity='0' d='M45.684,2.654c-6.057,0-11.27,4.927-13.684,10.073 c-2.417-5.145-7.63-10.073-13.687-10.073c-8.349,0-15.125,6.776-15.125,15.127c0,16.983,17.134,21.438,28.812,38.231 c11.038-16.688,28.811-21.787,28.811-38.231C60.811,9.431,54.033,2.654,45.684,2.654z'/>
#   </svg>
# {% elsif settings.app_wk_icon == "star" %}
#   <svg version='1.1' xmlns='http://www.w3.org/2000/svg' width='64' height='60.9' viewBox='0 0 64 64'>
#     <path d='M63.92,23.25a1.5,1.5,0,0,0-1.39-1H40.3L33.39,1.08A1.5,1.5,0,0,0,32,0h0a1.49,1.49,0,0,0-1.39,1L23.7,22.22H1.47a1.49,1.49,0,0,0-1.39,1A1.39,1.39,0,0,0,.6,24.85l18,13L11.65,59a1.39,1.39,0,0,0,.51,1.61,1.47,1.47,0,0,0,.88.3,1.29,1.29,0,0,0,.88-0.3l18-13.08L50,60.68a1.55,1.55,0,0,0,1.76,0,1.39,1.39,0,0,0,.51-1.61l-6.9-21.14,18-13A1.45,1.45,0,0,0,63.92,23.25ZM42.75,36.18a1.39,1.39,0,0,0-.51,1.61l5.81,18L32.85,44.69a1.41,1.41,0,0,0-1.67,0L15.92,55.74l5.81-18a1.39,1.39,0,0,0-.51-1.61L6,25.12H24.7a1.49,1.49,0,0,0,1.39-1L32,6.17l5.81,18a1.5,1.5,0,0,0,1.39,1H58Z' fill='#be8508'></path>
#   </svg>
# {% endif %}
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-icon-remove" type="text/x-template">
#          <svg version='1.1' xmlns='http://www.w3.org/2000/svg' width='320' height='320' viewBox='0 0 320 320'>
#    <g>
#      <path fill='#000000' stroke-width='0.25pt' d='m100,60l-40,40l170,170l40,-40l-170,-170z'/>
#      <path fill='#000000' stroke-width='0.25pt' d='m60,230l170,-170l40,40l-170,170l-40,-40z'/>
#    </g>
#   </svg>
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-link" type="text/x-template">
#          {% if wishlist.item_count %}
#   {% assign link_icon = 'wishlist-icon-filled' %}
# {% else %}
#   {% assign link_icon = 'wishlist-icon-empty' %}
# {% endif %}
# <a href="{{ wishlist.url }}" class="wk-link wk-{{ wishlist.state }}" title="View Wishlist">
#   <span id="CartCount" class="wk-count">{{ wishlist.item_count }}</span>
#   <div class="wk-icon">{% include link_icon %}</div>
# </a>
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-link-li" type="text/x-template">
#          <li class="wishlist-link-li wk-{{ wishlist.state }}">
#   {% include 'wishlist-link' %}
# </li>
#         </script>
#         <script app="wishlist-king" data="product" id="wishlist-button-product" type="text/x-template">
#          {% if product.in_wishlist %}
#   {% assign btn_text = 'In Wishlist' %}
#   {% assign btn_title = 'Remove from Wishlist' %}
#   {% assign btn_action = 'wk-remove-product' %}
#   {% assign btn_icon = 'wishlist-icon-filled' %}
# {% else %}
#   {% assign btn_text = 'Add to Wishlist' %}
#   {% assign btn_title = 'Add to Wishlist' %}
#   {% assign btn_action = 'wk-add-product' %}
#   {% assign btn_icon = 'wishlist-icon-empty' %}
# {% endif %}
#
# <button type="button" class="wk-button-product {{ btn_action }}" title="{{ btn_title }}" data-{{ btn_action }}="{{ product.id }}">
#   <div class="wk-icon">
#     {% include btn_icon %}
#   </div>
# </button>
#         </script>
#         <script app="wishlist-king" data="product" id="wishlist-button-collection" type="text/x-template">
#          {% if product.in_wishlist %}
#   {% assign btn_text = 'In Wishlist' %}
#   {% assign btn_title = 'Remove from Wishlist' %}
#   {% assign btn_action = 'wk-remove-product' %}
#   {% assign btn_icon = 'wishlist-icon-filled' %}
# {% else %}
#   {% assign btn_text = 'Add to Wishlist' %}
#   {% assign btn_title = 'Add to Wishlist' %}
#   {% assign btn_action = 'wk-add-product' %}
#   {% assign btn_icon = 'wishlist-icon-empty' %}
# {% endif %}
#
# <button type="button" class="wk-button-collection {{ btn_action }}" title="{{ btn_title }}" data-{{ btn_action }}="{{ product.id }}">
#   <div class="wk-icon">
#     {% include btn_icon %}
#   </div>
# </button>
#         </script>
#         <script app="wishlist-king" data="product" id="wishlist-button-wishlist-page" type="text/x-template">
#          {% if wishlist.read_only %}
#   {% assign item_id = product.id %}
# {% else %}
#   {% assign item_id = product.wishlist_item_id %}
# {% endif %}
#
# {% assign add_class = '' %}
# {% if product.in_wishlist and wishlist.read_only == true %}
#   {% assign btn_text = 'In Wishlist' %}
#   {% assign btn_title = 'Remove from Wishlist' %}
#   {% assign btn_action = 'wk-remove-product' %}
#   {% assign btn_icon = 'wishlist-icon-filled' %}
# {% elsif product.in_wishlist and wishlist.read_only == false %}
#   {% assign btn_text = 'In Wishlist' %}
#   {% assign btn_title = 'Remove from Wishlist' %}
#   {% assign btn_action = 'wk-remove-item' %}
#   {% assign btn_icon = 'wishlist-icon-remove' %}
#   {% assign add_class = 'wk-with-hover' %}
# {% else %}
#   {% assign btn_text = 'Add to Wishlist' %}
#   {% assign btn_title = 'Add to Wishlist' %}
#   {% assign btn_action = 'wk-add-product' %}
#   {% assign btn_icon = 'wishlist-icon-empty' %}
#   {% assign add_class = 'wk-with-hover' %}
# {% endif %}
#
# <button type="button" class="wk-button-wishlist-page {{ btn_action }} {{ add_class }}" title="{{ btn_title }}" data-{{ btn_action }}="{{ item_id }}">
#   <div class="wk-icon">
#     {% include btn_icon %}
#   </div>
# </button>
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-button-wishlist-clear" type="text/x-template">
#          {% assign btn_text = 'Clear Wishlist' %}
# {% assign btn_title = 'Clear Wishlist' %}
# {% assign btn_class = 'btn wk-button-wishlist-clear' %}
# <div class="u-block text-center u-paddingTopBottom4x">
# <button type="button" class="{{ btn_class }}" title="{{ btn_title }}" data-wk-clear-wishlist="{{ wishlist.permaId }}">
#   <span class="wk-label">{{ btn_text }}</span>
# </button>
# </div>
#         </script>
#         <script app="wishlist-king" data="shared_wishlist" id="wishlist-shared" type="text/x-template">
#          {% assign wishlist = shared_wishlist %}
# {% include 'wishlist-collection' with wishlist %}
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-collection" type="text/x-template">
#          <div class='wishlist-collection'>
# {% if wishlist.item_count == 0 %}
#   {% include 'wishlist-collection-empty' %}
# {% else %}
#   {% if customer_accounts_enabled and customer == false and wishlist.read_only == false %}
#     {% include 'wishlist-collection-login-note' %}
#   {% endif %}
#
#   {% if settings.app_wk_share_position == "top" %}
#     {% unless wishlist.read_only %}
#       {% include 'wishlist-collection-share' %}
#     {% endunless %}
#   {% endif %}
#
#   {% include 'wishlist-collection-loop' %}
#
#   {% if settings.app_wk_share_position == "bottom" %}
#     {% unless wishlist.read_only %}
#       {% include 'wishlist-collection-share' %}
#     {% endunless %}
#   {% endif %}
#
#   {% unless wishlist.read_only %}
#     {% include 'wishlist-button-wishlist-clear' %}
#   {% endunless %}
# {% endif %}
# </div>
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-collection-empty" type="text/x-template">
#          <div class="wk-row">
#   <div class="wk-span12">
#     <h6 class="text-center wk-wishlist-empty-note">Your wishlist is empty!</h6>
#   </div>
# </div>
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-collection-login-note" type="text/x-template">
#          <div class="u-block wk-row">
#   <h6 class="text-center u-marginBottom2x">
#     To permanently save your wishlist please <a href="/account/login">login</a> or <a href="/account/register">sign up</a>.
#   </h6>
# </div>
#         </script>
#         <script app="wishlist-king" data="wishlist" id="wishlist-collection-share" type="text/x-template">
#          <h3 id="wk-share-head">Share Wishlist</h3>
#   <ul id="wk-share-list">
#     <li>{% include 'wishlist-share-button-fb' %}</li>
#     <li>{% include 'wishlist-share-button-pinterest' %}</li>
#     <li>{% include 'wishlist-share-button-twitter' %}</li>
# ...
#      </script>
#      <script type="text/javascript">
#       document.getElementById("navigation-2_0").focus();
#      </script>
#      <style type="text/css">
#       .site-footer{color:#fff}.footer-copyright{color:#fff}.disclaimer a:hover{text-decoration:underline}.disclaimer.de-u-spaceTop1 a{color:#008FD6;text-decoration:underline}.disclaimer.de-u-spaceTop1 a:hover{color:#11AFFF}.disclaimer.de-u-spaceTop1 a:focus{color:#11AFFF}.footerNav-link{color:#fff}
#      </style>
#     </div>
#    </div>
#    <div class="de-searchModal js-de-searchModal" id="searchModal">
#     <div aria-hidden="true" class="de-searchContainer" data-de-page-wrap-cancel="" id="search-container">
#      <form action="/search">
#       <input autocomplete="off" class="js-de-searchInput" data-gtm-category="Search Modal" data-gtm-event="customer-interaction" data-gtm-id="Search Bar" name="q" placeholder="Search" type="search" value=""/>
#       <div class="de-searchSubmitOut">
#        <input aria-label="Search Button" class="js-de-searchSubmit" disabled="" type="submit" value=""/>
#       </div>
#      </form>
#      <span class="js-de-searchPopularTitle">
#       Popular Search Terms
#      </span>
#      <ul class="js-de-searchPopular">
#       <li>
#        <a href="/search?q=backpacks">
#         Backpacks
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=tents">
#         Tents
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=fleeces">
#         Fleeces
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=bikes">
#         Bikes
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=quechua">
#         Quechua
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=jackets">
#         Jackets
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=towels">
#         Towels
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=yoga mat">
#         Yoga Mat
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=sleeping bag">
#         Sleeping Bag
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=socks">
#         Socks
#        </a>
#       </li>
#       <li>
#        <a href="/search?q=gloves">
#         Gloves
#        </a>
#       </li>
#      </ul>
#      <span class="js-de-searchReplyTitle">
#       Top Suggestions
#      </span>
#      <ul class="js-de-searchReply">
#      </ul>
#      <div class="de-nav-close" data-de-page-wrap-action="closeMenu" data-de-page-wrap-target="search-container">
#       <img alt="Close" aria-label="Close Search Dialog" class="de-nav-close-img js-de-searchDialogClose" role="button" src="//www.decathlon.com/cdn/shop/t/242/assets/grey-close.png?v=114391736289926610551667891748" tabindex="0"/>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/timber.js?v=9151286809320365391667891936" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://polyfill.io/v3/polyfill.min.js?flags=gated&amp;features=fetch%2CURL%2CArray.prototype.includes%2CSymbol.iterator%2CArray.prototype.find%2CDOMTokenList.prototype.%40%40iterator%2CDOMTokenList%2CSymbol.isConcatSpreadable%2CArray.from%2CArray.prototype.findIndex%2CElement.prototype.closest%2CElement.prototype.matches%2CObject.assign%2CNodeList.prototype.forEach%2CString.prototype.includes%2CObject.values%2CArray.prototype.flatMap%2CCustomEvent%2CPromise.prototype.finally">
#   </script>
#   <script defer="" src="//www.decathlon.com/cdn/shop/t/242/assets/built-persistent-cart.js?v=84261728192690668651705607093" type="module">
#   </script>
#   <script defer="" src="//www.decathlon.com/cdn/shop/t/242/assets/built-cart-count.js?v=160765088224151811621705607125" type="module">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/built-product-tile.js?v=123362783049257261271705607139" type="module">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/built-product-carousel.js?v=61759917002273849291705607121" type="module">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/built-dy-product-tile-carousel.js?v=164396609483353783211705607149" type="module">
#   </script>
#   <script>
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/handlebars.min.js?v=79044469952368397291667891749" type="text/javascript">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/ajax-cart.js?v=91290901626927454531686241973" type="text/javascript">
#   </script>
#   <script>
#    jQuery(function($) {
#       if ($('.timber-activeProduct').length > 0) {
#         ajaxCart.init({
#           formSelector: '.addToCartForm',
#           cartContainer: '#CartContainer',
#           addToCartSelector: '.addToCart',
#           cartCountSelector: '#CartCount',
#           cartCostSelector: '#CartCost',
#           moneyFormat: "${{amount}}"
#         });
#       }
#     });
#   </script>
#   <!-- /snippets/added-item-popup-template.liquid -->
#   <script id="AddedItemTemplate" type="text/template">
#    <div id="AddedItemPopup" class="de-AddedItemPopup {{#if multiple_products}}itemPopup--multipleProducts{{/if}}{{#if isWishlist}} itemPopup--wishlist{{/if}}">
#   <div class="close-itemPopup-btn de-u-textBlack de-u-pad06 de-u-flex">
#     <svg class="de-Icon de-u-textGrow1" viewBox="0 0 16 16">
#   <polygon points="12.78 1.806 8 6.586 3.22 1.806 1.806 3.22 6.586 8 1.806 12.78 3.22 14.194 8 9.414 12.78 14.194 14.194 12.78 9.414 8 14.194 3.22 12.78 1.806"/>
# </svg>
#
#   </div>
#   <div class="wrapper">
#     <div class="u-flex-list u-flex-list--line">
#       <div class="u-flex-listItem itemPopup-headerFlex">
#         <h4 class="itemPopup-header de-u-textBlack">Added to {{#if isWishlist}}wishlist{{else}}cart{{/if}}:</h4>
#       </div>
#       <div class="u-flex-listItem itemPopup-productFlex">
#         <div class="itemPopup-productCenter">
#           {{#each multiple_products}}
#             <p class="itemPopup-title">{{this}}</p>
#           {{/each}}
#           {{#unless multiple_products}}
#             <img class="itemPopup-image" src="{{image}}" alt="{{product_title}}" />
#
#             <h3 class="de-u-textGrow1 de-u-md-textGrow2 de-u-textMedium de-u-spaceBottomNone de-u-lineHeight1">{{product_title}}</h3>
#
#             <div class="itemPopup-details">
#               <div class="de-u-textDarkGray">
#               {{#each variant_options_without_model_code}}
#                 <span>{{this}}</span>
#                 {{#unless @last}}|{{/unless}}
#               {{/each}}
#               </div>
#               <div class="de-u-textGrow1 de-u-md-textGrow2 de-u-textMedium de-u-spaceTop05">
#                 <span>Qty: {{added_quantity}}</span>
#                 <span>{{price_dollars}} ea</span>
#               </div>
#             </div>
#           {{/unless}}
#         </div>
#       </div>
#       <div class="u-flex-listItem itemPopup-infoFlex">
#         <div class="itemPopup-image"></div>
#         <div class="itemPopup-infoWrap u-block">
#           {{#unless isWishlist}}
#           <h5 class="de-u-textGrow1 de-u-md-textGrow2 de-u-textMedium de-u-spaceBottomNone de-u-lineHeight1">Cart subtotal: {{subtotal}}</h5>
#           <p class="de-u-textDarkGray de-u-spaceTopNone de-u-textShrink">Shipping &amp; taxes calculated at checkout</p>
#           {{/unless}}
#           <p>
#             {{#if isWishlist}}
#             <a class="itemPopup-submitCart btn btn--full" href="/pages/wishlist">View Wishlist</a>
#             {{else}}
#             <a class="itemPopup-viewCart btn" href="/cart">View Cart</a>
#             <a class="itemPopup-submitCart btn btn--fill js-submitCart js-de-checkout" href="/checkout">Checkout</a>
#             {{/if}}
#           </p>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/slick.min.js?v=89980774482270015571667891936" type="text/javascript">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/js.cookie.min.js?v=157586561987493936911667891789" type="text/javascript">
#   </script>
#   <script>
#    ;(function(window, $, Cookies) {
#     $(function() {
#
#       // Alan - 030618 - added for native app to clear localStorage
#       if (Cookies.get('noLocalStorage')) {
#         localStorage.clear();
#         Cookies.remove('noLocalStorage');
#       }
#
#     try {
#       Appmate.wk.ready(function(data) {
#         Cookies.set('helpdesk', {
#           cartCount: 0,
#           wishlistCount: Appmate.wk.collection.items.length
#         }, { domain: '.decathlon.com' });
#       });
#     } catch(e) {}
#
#     });
#     })(window, jQuery, Cookies);
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/built-decathlon-legacy.js?v=167334700685874904471678219048" type="text/javascript">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/patterns-toolkit.js?v=70900353422803787481667891827" type="text/javascript">
#   </script>
#   <script defer="" src="//www.decathlon.com/cdn/shop/t/242/assets/built-tooltip.js?v=22135617354625907161705607161" type="module">
#   </script>
#   <script type="text/javascript">
#    window.addToWishlist = false;
#
# $(function() {
#   window.wishlistSwap = decathlon.wishlistSwap();
# });
#   </script>
#   <div data-api-root="https://5plerphfc8.execute-api.us-west-2.amazonaws.com/1_1" data-api-root-v2="https://us-central1-dkt-us-data-lake-a1xq.cloudfunctions.net/sf-dkt-shopify-activation-email-prod" data-api-root-v3="https://sf-dkt-shopify-customers-api-prod-y7jflx25za-uc.a.run.app/api/v1" id="decathlon-customer-api">
#   </div>
#   <script>
#    window.shipStates = ["all"];
#   </script>
#   <script type="text/javascript">
#    if (window.navigator.language === 'en-US') {
#       var mouseflowCrossDomainSupport = true;
#       window._mfq = window._mfq || [];
#       (function() {
#         var mf = document.createElement("script");
#         mf.type = "text/javascript";
#         mf.defer = true;
#         mf.src = "//cdn.mouseflow.com/projects/3c536446-71f3-4a65-8c6e-6e254c934dff.js";
#         document.getElementsByTagName("head")[0].appendChild(mf);
#       })();
#     }
#   </script>
#   <input class="js-de-cart-count" type="hidden" value="0"/>
#   <input class="js-de-cid" type="hidden" value=""/>
#   <input class="js-de-money-format" type="hidden" value="${{amount}}"/>
#   <script type="text/javascript">
#    (function() {
#       var avm = document.createElement('script'); avm.type = 'text/javascript'; avm.async = true;
#       avm.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.avmws.com/1016785/';
#       var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(avm, s);
#     })();
#   </script>
#   <!--Gorgias Chat Widget Start-->
#   <div id="gorgias-chat">
#    <script>
#     window.gorgiasChatParameters = {"smooch": {"properties": {"shopify__cart__total_price": "$0.00","shopify__cart__nb_of_items": 0,}}}
#    </script>
#    <script id="gorgias-chat-widget-install">
#     var HIDE_POWERED_BY_GORGIAS = true;
#
# !function(_){_.GORGIAS_CHAT_APP_ID="2191",_.GORGIAS_CHAT_BASE_URL="us-east1-898b.production.gorgias.chat",_.GORGIAS_API_BASE_URL="config.gorgias.chat";var e=new XMLHttpRequest;e.open("GET","https://config.gorgias.chat/applications/2191",!0),e.onload=function(t){if(4===e.readyState)if(200===e.status){var n=JSON.parse(e.responseText);if(!n.application||!n.bundleVersion)throw new Error("Missing fields in the response body - https://config.gorgias.chat/applications/2191");if(_.GORGIAS_CHAT_APP=n.application,_.GORGIAS_CHAT_BUNDLE_VERSION=n.bundleVersion,n&&n.texts&&(_.GORGIAS_CHAT_TEXTS=n.texts),n&&n.sspTexts&&(_.GORGIAS_CHAT_SELF_SERVICE_PORTAL_TEXTS=n.sspTexts),!document.getElementById("gorgias-chat-container")){var o=document.createElement("div");o.id="gorgias-chat-container",document.body.appendChild(o);var r=document.createElement("script");r.setAttribute("defer",!0),r.src="https://client-builds.production.gorgias.chat/{bundleVersion}/static/js/main.js".replace("{bundleVersion}",n.bundleVersion),document.body.appendChild(r)}}else console.error("Failed request GET - https://config.gorgias.chat/applications/2191")},e.onerror=function(_){console.error(_)},e.send()}(window||{});
#    </script>
#   </div>
#   <!--Gorgias Chat Widget End-->
#   <script>
#    var _learnq = _learnq || [];
#     if ('') {
#       _learnq.push(['identify', {
#         '$email' : ''
#         }]);
#     }
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/inert.min.js?v=11564935774855731651667891772" type="text/javascript">
#   </script>
#   <script src="//www.decathlon.com/cdn/shop/t/242/assets/custom-mob-nav.js?v=113844905373142264381667891730" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# With the parsed HTML, we can now extract specific elements.

# %% [markdown]
# #### Extracting Data

# %% [markdown]
# `find` and `findAll` (or its equivalent `find_all`) are methods used to search the soup tree for tags that match a certain criterion.
#
# 1. **find**:
#     - Returns only the **first** tag that matches a given set of criteria.
#     - Useful when you know there's only one tag of interest or you only want the first occurrence.
#     - Example: If you have multiple `<p>` tags on a page and you use `soup.find('p')`, you'll get only the first `<p>` tag.
#
# 2. **findAll (or find_all)**:
#     - Returns a **list** of tags that match the given criteria.
#     - Useful when you want to capture all occurrences of a particular tag or set of tags.
#     - Example: Using `soup.find_all('p')` will give you a list containing all `<p>` tags on the page.
#
# Here's a simple illustration:
#
# ```html
# <html>
#     <body>
#         <p>First paragraph.</p>
#         <p>Second paragraph.</p>
#         <div>Some div.</div>
#     </body>
# </html>
# ```
#
# Using `find('p')` would return the "First paragraph." while `find_all('p')` would return a list containing both "First paragraph." and "Second paragraph.".

# %% [markdown]
# Let's look at different ways of extracting data.

# %% [markdown]
# ##### **By Tag**

# %% [markdown]
# Let's start with a popular tag: `title`.

# %%
soup.find("title") # Find the first <title> tag on the page
# Out:
# <title>
#     Mountain Bikes | Decathlon
#     </title>

# %%
soup.find_all("title") # Find the all <title> tags on the page
# Out:
# [<title>
#      Mountain Bikes | Decathlon
#      </title>,
#  <title id="logo-title">Decathlon</title>,
#  <title id="logo-title">Decathlon</title>,
#  <title id="logo-title">Decathlon</title>,
#  <title>Decathlon Rockrider</title>,
#  <title>Decathlon Rockrider</title>,
#  <title>product-research</title>,
#  <title>laptop-checkout</title>]

# %% [markdown]
# ##### **By Class**

# %% [markdown]
# To search for HTML elements by class in a webpage using BeautifulSoup, you can also use the `find` and `find_all` methods.
#
# 1. **Using `find` method to get the first matching element**:
#
#    ```python
#    result = soup.find(class_='your-class-name')
#    ```
#
# 2. **Using `find_all` method to get a list of all matching elements**:
#
#    ```python
#    results = soup.find_all(class_='your-class-name')
#    ```
#
# Note that we are using the `class_` parameter because `class` is a reserved keyword in Python.

# %% [markdown]
# Let's dive into our target URL and explore its structure. Our objective is to craft a dataframe populated with bicycle names and their corresponding prices.
#
# To pinpoint the exact tags housing this information, follow these steps:
# 1. Navigate to the website in your browser.
# 2. Locate a bicycle name, right-click on it, and choose 'Inspect'. This action will direct you to the element within the site's HTML. Identify the tags so we can extract our desired data.
# 3. Repeat the same process for the price.

# %% [markdown]
# Note: the bicycle names and prices will change depending on the newest bikes in the shop.

# %% [markdown]
# Let's filter all elements which `class` is `de-ProductTile-title`.

# %%
soup.find_all(class_='de-ProductTile-title')
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>]

# %% [markdown]
# In this case, the results of `class` `de-ProductTile-title` are all inside `h4` tags and we actually got the information we wanted. But what if the `class` `de-ProductTile-title` was inside different `tags` and we only want the results of the `tag h4`?

# %% [markdown]
# ##### **By Tag and Class**

# %% [markdown]
# BeautifulSoup allows filtering results using combinations, such as filtering by tag and class.

# %% [markdown]
# ```python
# tags = soup.find_all(name=tag_name, class_=class_name)
# ```

# %% [markdown]
# We can use a for loop to iterate over the results and do whatever we need to do.

# %% [markdown]
# To extract the names from the provided HTML content, you can:
#
# 1. Use the `find_all` or `findAll` method to locate the `<h4>` tags with the specific class (`de-ProductTile-title` in this case).
# 2. Extract the text from the found tag.

# %%
# Find all <h4> tags with class "de-ProductTile-title"
bike_names_tags = soup.find_all('h4', class_='de-ProductTile-title')
bike_names_tags
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>]

# %%
# find_all returns a list
bike_names_tags[:3]
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>]

# %%
type(bike_names_tags) # What type is it?
# Out:
# bs4.element.ResultSet

# %%
# Lets look at how many elements we retrieved
len(bike_names_tags)
# Out:
# 2

# %%
# Lets look at the first element
bike_names_tags[0]
# Out:
# <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#           Rockrider RACE 900S GX Eagle XC Mountain Bike
#         </h4>

# %%
# We can get the actual text using .text, .getText() or .get_text()
print(bike_names_tags[0].text)
print(bike_names_tags[0].getText())
print(bike_names_tags[0].get_text())
# Out:
#           Rockrider RACE 900S GX Eagle XC Mountain Bike
#
#
#           Rockrider RACE 900S GX Eagle XC Mountain Bike
#
#
#           Rockrider RACE 900S GX Eagle XC Mountain Bike

# %%
# Lets get rid of all the white spaces
bike_names_tags[0].getText().strip()
# Out:
# 'Rockrider RACE 900S GX Eagle XC Mountain Bike'

# %%
# Create a new list only with bicycle names
names = [bike.text.strip() for bike in bike_names_tags]
names
# Out:
# ['Rockrider RACE 900S GX Eagle XC Mountain Bike',
#  'Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"']

# %% [markdown]
# To extract the price from the provided HTML content, you can:
#
# 1. Use the `find_all` method to locate the `<span>` tags with the specific class (`js-de-ProductTile-currentPrice` in this case).
# 2. Extract the text from the found tag.

# %%
# Find the <span> tag and get its text
prices = soup.find_all('span', class_='js-de-ProductTile-currentPrice')
prices
# Out:
# [<span class="js-de-ProductTile-currentPrice">$5,999.00</span>,
#  <span class="js-de-ProductTile-currentPrice">$2,499.00</span>]

# %%
prices[0].text
# Out:
# '$5,999.00'

# %%
for price_tag in prices:
    print(price_tag.text)
# Out:
# $5,999.00
# $2,499.00

# %% [markdown]
# ##### **Getting other attributes**

# %% [markdown]
# To access other attribute values such as hyperlinks (which are usually contained in the `href` attribute of `a` tags), you first locate the element using BeautifulSoup methods such as `find` or `find_all`, and then use the `.get()` method to retrieve the value of the attribute you're interested in. Here is a step-by-step explanation:
#
# 1. **Locate the element**: Use `find` or `find_all` to locate the element(s) that contain the attribute you want to access.
#
#     ```python
#     link_element = soup.find('a', class_='link-class')
#     ```
#
# 2. **Access the attribute**: Once you have the element, use the `.get()` method to access the attribute value.
#
#     ```python
#     link_url = link_element.get('href')
#     ```
#
# In the above snippet:
# - We first find the `a` element with the class `'link-class'`.
# - We then get the value of the `href` attribute which contains the hyperlink.

# %% [markdown]
# When inspecting the website, we saw that the bicycle title was a link. How can we get that link?
# Lets inspect the whole element containing the bicycle name instead of just the name.
#
# We can see that we have:
#
#     <a class="de-u-linkClean js-de-ProductTile-link" href="/collections/mountain-bikes/products/mountain-bike-275-rockrider-st-100-196952-192872">
#
# Note: this link will change depending on the newest bike in the shop.

# %%
# Find the <a> tag and get its href attribute
#print(soup.find('a', class_='de-u-linkClean js-de-ProductTile-link'))#.get('href')
print(soup.find('a', class_='js-de-ProductTile-link').get("href"))
print(soup.find('a', class_='js-de-ProductTile-link')["href"])
# Out:
# /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357
# /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357

# %%
# Extracting all links within <a> tags and class 'de-u-linkClean js-de-ProductTile-link'
for link in soup.find_all('a', class_='js-de-ProductTile-link'):
    print(link.get('href'))
# Out:
# /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357
# /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357
# /collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990
# /collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990

# %% [markdown]
# #### More filtering options

# %% [markdown]
# ##### Filtering by Multiple Tags

# %% [markdown]
# To find elements with multiple possible tags, you can pass a list of tag names to `find_all`.

# %%
# Find all <div> and <span> tags
soup.find_all(['div', 'span'])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##### Filtering by Multiple Classes

# %% [markdown]
# To find elements with multiple possible classes, you can pass a list of class names.

# %%
# Find all elements with class 'js-de-ProductTile-currentPrice' or 'de-ProductTile-title'
soup.find_all(class_=['js-de-ProductTile-currentPrice', 'de-ProductTile-title'])
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <span class="js-de-ProductTile-currentPrice">$5,999.00</span>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>,
#  <span class="js-de-ProductTile-currentPrice">$2,499.00</span>]

# %% [markdown]
# ##### Combining Multiple Criteria

# %% [markdown]
# You can combine multiple criteria by using the `attrs` argument.

# %%
# Find all <h4> or <span> tags with class "class1" or "class2"
soup.find_all(['h4', 'span'], attrs={"class": ['js-de-ProductTile-currentPrice', 'de-ProductTile-title']})
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <span class="js-de-ProductTile-currentPrice">$5,999.00</span>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>,
#  <span class="js-de-ProductTile-currentPrice">$2,499.00</span>]

# %% [markdown]
# ##### Limiting the Results

# %% [markdown]
# You can limit the number of results returned by `find_all` using the `limit` parameter.

# %%
# Only get the first 5 <h4> tags
soup.find_all('h4', limit=5)
# Out:
# [<h4 class="message-title">
#                                      Winter Sale - Up to 40% Off!
#                                  </h4>,
#  <h4 class="message-title">
#                                          Adventure On
#                                      </h4>,
#  <h4 class="message-title">
#                                          Free Shipping | Click &amp; Collect
#                                      </h4>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>]

# %% [markdown]
# ##### Navigating through the "Tree" of HTML Elements
#
# Beautiful Soup provides a robust set of tools that allow you to traverse and explore the hierarchical structure of an HTML document, often referred to as the "tree".
#
# To access child elements directly:

# %%
soup.div.find_all("h4")
# Out:
# [<h4 class="message-title">
#                                      Winter Sale - Up to 40% Off!
#                                  </h4>,
#  <h4 class="message-title">
#                                          Adventure On
#                                      </h4>,
#  <h4 class="message-title">
#                                          Free Shipping | Click &amp; Collect
#                                      </h4>]

# %% [markdown]
# The code above will first locate the initial `div` element present in the Beautiful Soup object. Subsequently, it will fetch all `h4` elements contained within that `div`.
#
# But what if you need to retrieve a specific child by its position, say the second child?

# %%
soup.div.find_all("h4")[1]
# Out:
# <h4 class="message-title">
#                                         Adventure On
#                                     </h4>

# %% [markdown]
# #### Creating a DataFrame with the data

# %% [markdown]
# Instead of getting names and prices separately, we can target the whole component, and extract the name and price from each bicycle component in a more structured manner. By targeting this whole component tag, we can ensure that we are extracting information for the same product (i.e., the name and price correspond to the same bicycle).
#
# Here's how we can achieve this:
#
# 1. **Targeting the Whole Component**:
#    - Instead of targeting individual tags for names and prices, we target the main component that houses both the name and price.
#    - By visually inspecting the HTML, we can see that:
#        - The information for each bicycle (name, price, etc.) is grouped together under a `<section>` tag.
#        - The `class` attribute of this `<section>` tag is `de-ProductTile-info`. This class seemed specific to the product tile and thus, a good candidate to use for extraction.
#
# 2. **Iterating through Components**:
#    - For each such component, extract the name and the price.
#
# 3. **Storing Data**:
#    - Store the extracted data in lists, which can then be used to create a DataFrame.

# %%
import pandas as pd

# Lists to store extracted data
bicycle_names = []
prices = []

# Find all components
components = soup.find_all('div', class_='de-ProductTile-info')

for component in components:
    # Extract bicycle name
    #component
    bike_name = component.find('h4', class_='de-ProductTile-title').text.strip()
    bicycle_names.append(bike_name)

    # Extract price
    price = component.find('span', class_='js-de-ProductTile-currentPrice').text.strip().replace("$", "")
    prices.append(price)

# Create DataFrame
df = pd.DataFrame({
    'Bicycle_Name': bicycle_names,
    'Price': prices
})

df
# Out:
#                                         Bicycle_Name     Price
# 0      Rockrider RACE 900S GX Eagle XC Mountain Bike  5,999.00
# 1  Rockrider AM Fifty_S 12-Speed Full Suspension ...  2,499.00

# %% [markdown]
# We could further clean our dataset to ensure the price is a float, facilitating arithmetic operations. This implies prices shouldn't be in a range.

# %% [markdown]
# #### 💡 Check for understanding

# %% [markdown]
# You are given a raw HTML content of a product list from an online store. Your task is to extract the following details for each product:
#
# - Bicycle Name
# - Bicycle Price
# - URL for the product details
# - URL for the product image
#
# Write a function extract_bike_info that takes in the HTML content and returns a pandas DataFrame with the above columns.
#
# **Hint:**
#
# In order to get the product image, it might be a good idea to use the `article` tag with the class `de-ProductTile` since based on the HTML structure, this `article` tag encapsulates the entire product, including both the image and the product details. This allows us to more easily access all the relevant details for each product without having to jump around different sections.
#
# If we were to only use `soup.find_all('section', class_='de-ProductTile-info')`, we'd be focusing solely on the product details section and would then need a separate approach to extract the image URL. By starting with the `article` tag, we're able to extract all the needed data in a more cohesive and streamlined manner.
#
# **Bonus:** clean the price column so you can make numerical operations.

# %%
def extract_bike_info(soup):
    # Lists to store extracted data
    bicycle_names = []
    prices = []
    url_product_details = []
    url_product_images = []

    # Find all components
    components = soup.find_all('div', class_='de-ProductTile-info')

    for component in components:
        # Extract bicycle name
        #component
        bike_name = component.find('h4', class_='de-ProductTile-title').text.strip()
        bicycle_names.append(bike_name)

        # Extract price
        price = component.find('span', class_='js-de-ProductTile-currentPrice').text.strip().replace("$", "")
        prices.append(price)

        # Product details
        url_details = component.find('a', class_='de-u-linkClean js-de-ProductTile-link js-de-ProductTile-box').get("href")
        url_product_details.append(url_details)

        # Product image
        product_image = component.find('img').get('data-src')
        url_product_images.append("https:"+product_image)

    # Create DataFrame
    df = pd.DataFrame({
        'Bicycle_Name': bicycle_names,
        'Price': prices,
        'Details': url_product_details,
        'Image': url_product_images
        })
    return df

# %%
df = extract_bike_info(soup)
df
# Out:
#                                         Bicycle_Name     Price  \
# 0      Rockrider RACE 900S GX Eagle XC Mountain Bike  5,999.00
# 1  Rockrider AM Fifty_S 12-Speed Full Suspension ...  2,499.00
#
#                                              Details  \
# 0  /collections/mountain-bikes/products/rockrider...
# 1  /collections/mountain-bikes/products/rockrider...
#
#                                                Image
# 0  https://www.decathlon.com/cdn/shop/files/88327...
# 1  https://www.decathlon.com/cdn/shop/products/86...

# %% [markdown]
# #### Scraping many pages

# %% [markdown]
# When dealing with a limited number of bicycles, all products are conveniently displayed on a single page. But what if there were numerous products necessitating pagination across multiple pages?
#
# Consider the 'deals' collection. By navigating to the end of its first page on the website, we can observe pagination links. Transitioning to the second page results in a change in the URL:
#
# From:
# "https://www.decathlon.com/collections/deals"
# To:
# "https://www.decathlon.com/collections/deals?page=2"
#
# This pattern in the URL can be leveraged to generate a series of URLs for web scraping.
#
# Please note: Depending on the current offers available at the time of this lesson, pagination might not be present. If that's the case, explore other product categories that have a substantial number of items, resulting in multiple pages.

# %%
pages = [f"https://www.decathlon.com/collections/deals?page={pag}" for pag in range(1,5)]

# %%
pages
# Out:
# ['https://www.decathlon.com/collections/deals?page=1',
#  'https://www.decathlon.com/collections/deals?page=2',
#  'https://www.decathlon.com/collections/deals?page=3',
#  'https://www.decathlon.com/collections/deals?page=4']

# %%
def get_df_from_url(url):

    response = requests.get(url)

    soup = BeautifulSoup(response.content, 'html.parser')
    df = extract_bike_info(soup)
    return df

# %%
dfs = [get_df_from_url(p) for p in pages]

# %%
dfs[1]
# Out:
#                                          Bicycle_Name          Price  \
# 0       Forclaz Men's MT100 Hooded Down Puffer Jacket  80.00 — 99.99
# 1     Quechua Men's SH100 Waterproof Mid Hiking Boots  35.00 — 49.99
# 2   Men's warm waterproof snow hiking boots - SH10...          35.00
# 3               Triban RoadR 100 Cycling Gloves Adult           5.00
# 4             Quechua NH100 Fresh Hiking Shorts Men's           6.00
# 5                  Quechua NH100 Hiking Sandals Men's          10.00
# 6     Forclaz Women's MT100 Hooded Down Puffer Jacket  80.00 — 99.99
# 7                Women's Hiking Fleece Jacket - MH120  20.00 — 29.99
# 8       Forclaz Women's MT100 Hooded Synthetic Jacket          50.00
# 9                    100 Base Layer Ski Pants Women's           6.00
# 10              Triban RoadR 100 Cycling Gloves Adult           5.00
# 11               Quechua Women's NH100 Hiking Sandals           8.00
#
#                                               Details  \
# 0   /collections/mens-deals/products/forclaz-mt100...
# 1   /collections/mens-deals/products/mens-warm-and...
# 2   /collections/mens-deals/products/mens-warm-wat...
# 3   /collections/mens-deals/products/road-cycling-...
# If you look at our results, and compare it with the website, you'll see that its not returning all the products. Each page has more than 9 products, and its only returning 9 on each page.
#
# This could be because the content is dynamic.
#
# **Dynamic Content**: Many modern websites use JavaScript to load content dynamically. When you make a request using libraries like requests, you only retrieve the initial HTML content. Content loaded dynamically via JavaScript after this won't be captured. In such cases, tools like Selenium are used because they can interact with the JavaScript of the page.

# %% [markdown]
# #### CSS selectors

# %% [markdown]
# CSS selectors are patterns used to select and manipulate one or more elements in an HTML or XML document. When web scraping with Python, CSS selectors can be used to target specific elements of interest within the page's content.

# %% [markdown]
# The `select` method in BeautifulSoup allows you to pass a CSS selector and returns a list of elements matching that selector.

# %% [markdown]
# 1. **Tag Selector**: Targets elements by their tag name.
#    - `p`: selects all `<p>` elements.
#    - `soup.select("p")` will retrieve all `<p>` elements
#
# 2. **Class Selector**: Targets elements by their class attribute.
#    - `.classname`: selects all elements with `class="classname"`.
#    - If class name has spaces, they must be changed by `.`
#    - `soup.select(".classname")`
#    - To combine both, we can have `soup.select("tagname.classname")`
#
# 3. **Descendant Selector**: Targets an element that is a descendant of another element.
#    - `div p`: selects all `<p>` elements inside a `<div>` element.
#    - `.class1 .class2`: selects all elements with class2 that is a descendant of an element with class1.
#
# 4. **Attribute Selector**: Targets elements based on their attributes and values.
#    - `a[href]`: selects all `<a>` elements with an `href` attribute.
#    - `a[href="https://www.example.com"]`: selects all `<a>` elements with an `href` value of "https://www.example.com".
#
# And more...

# %% [markdown]
# 1. **Tag Selector**:
#    - **`article`**: This would select all `<article>` elements on the page.

# %%
soup.select("article")
# Out:
# [<article class="de-ProductTile de-u-lineHeight3 de-u-bgWhite js-de-ProductTile de-ProductTile--gridAlternate" data-ga4-brand="Rockrider" data-ga4-category="Mountain Bike" data-ga4-price="599900" data-gtm-actions="click" data-gtm-category="Regular Collection" data-gtm-event="customer-interaction" data-gtm-id="Mountain Bikes | Rockrider RACE 900S GX Eagle XC Mountain Bike | /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-product-title="Rockrider RACE 900S GX Eagle XC Mountain Bike" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/Product" role="listitem">
#  <a aria-label="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="js-de-ProductTile-link" href="/collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" tabindex="-1">
#  <section class="de-ProductTile-showcase js-de-ProductTile-showcase">
#  <ul class="de-u-listReset de-u-spaceNone de-ProductTile-flagContainer de-u-textShrink1 de-u-md-textGrow">
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--blackfriday de-u-hidden">
#  <span aria-hidden="true">Black Friday</span>
#  <span class="de-u-hiddenVisually">Black Friday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--newdeal de-u-hidden">
#  <span aria-hidden="true">New Deal</span>
#  <span class="de-u-hiddenVisually">New Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--cybermonday de-u-hidden">
#  <span aria-hidden="true">Cyber Monday</span>
#  <span class="de-u-hiddenVisually">Cyber Monday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-lastCall de-ProductFlag--secondary de-u-hidden">
#  <span aria-hidden="true">Clearance</span>
#  <span class="de-u-hiddenVisually">Clearance product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-sale de-ProductFlag--sale de-u-hidden">
#  <span aria-hidden="true">Deal</span>
#  <span class="de-u-hiddenVisually">Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Best Seller</span>
#  <span class="de-u-hiddenVisually">Best Seller product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--ecogreen de-u-hidden">
#  <span aria-hidden="true">Ecodesign</span>
#  <span class="de-u-hiddenVisually">Ecodesign product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">New</span>
#  <span class="de-u-hiddenVisually">New product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Staff Pick</span>
#  <span class="de-u-hiddenVisually">Staff Pick product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">In The News</span>
#  <span class="de-u-hiddenVisually">In The News product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">Innovation</span>
#  <span class="de-u-hiddenVisually">Innovation product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true"></span>
#  <span class="de-u-hiddenVisually"> product</span>
#  </li>
#  </ul>
#  <div class="de-productTile-showcaseImageContainer">
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-ProductTile-showcaseImage de-section5Img-large js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_335x335.jpg?v=1695294985" itemprop="image" loading="lazy"/>
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-ProductTile-showcaseImage de-section5Img-desktop js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_264x264.jpg?v=1695294985" itemprop="image" loading="lazy"/>
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-ProductTile-showcaseImage de-section5Img-mobile" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_164x164.jpg?v=1695294985" itemprop="image" loading="lazy"/>
#  </div>
#  </section>
#  </a>
#  <div class="de-ProductTile-info">
#  <div aria-label="Colors available" class="de-SwatchObjects de-SwatchObjects--productTile de-u-md-padEnds06 js-de-ProductTile-defaults" data-default-available-variants="4" data-default-compare-at-price="" data-default-image="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_335x335.jpg?v=1695294985" data-default-image-alt="Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of" data-default-image2="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373143_fa092f65-883f-49ce-a1f2-4f16e4c35693_335x335.jpg?v=1695294986" data-default-image2-alt="Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of" data-default-is-free-shipping="true" data-default-is-last-call="false" data-default-is-sale="false" data-default-price="$5,999.00" data-default-price-varies="false" data-default-total-variants="4">
#  <a class="de-SwatchObjects-item de-ColorSwatches-color js-de-ColorSwatchList-action de-u-hidden" data-available-variants="4" data-color="White" data-compare-at-price-varies="false" data-compare-at-prices="none==none==none==none" data-gtm-category="Tiles" data-gtm-event="customer-interaction" data-gtm-id="Swatch 1 / 1 | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-image="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_large.jpg?v=1695294985" data-image-alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " data-image2="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373143_fa092f65-883f-49ce-a1f2-4f16e4c35693_large.jpg?v=1695294986" data-image2-alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " data-is-free-shipping="true" data-is-last-call="false" data-is-limited-availability="false" data-is-sale="false" data-price-varies="false" data-prices="599900==599900==599900==599900" data-prices-delimiter="==" data-product-id="7234696904766" data-total-variants="4" href="/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357?variant=40147947749438" itemprop="color" title="Available colors, White, 1 out of 1">
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-SwatchObject-image de-u-block" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_64x64.jpg?v=1695294985" height="64" loading="lazy" width="64"/>
#  </a>
#  </div>
#  <a class="de-u-linkClean js-de-ProductTile-link js-de-ProductTile-box" href="/collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357">
#  <header class="de-ProductTile-header js-de-ProductTile-header">
#  <svg class="de-ProductTile-brandLogo de-subBrandLogo" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Decathlon Brand | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" height="24" role="img" viewbox="0 0 175.2177 24" width="175.2177">
#  <title>Decathlon Rockrider</title>
#  <path d="M84.77544,6.65392h4.09725a3.5068,3.5068,0,0,1,3.81535,3.4679,3.23846,3.23846,0,0,1-1.96667,2.98935l2.48456,4.09724H90.67547L88.5908,13.64873H87.024v3.55968h-2.2289Zm2.2289,2.0519v2.89757H88.971a1.38319,1.38319,0,0,0,1.475-1.44879,1.38318,1.38318,0,0,0-1.475-1.44878Z"></path>
#  <path d="M100.09585,17.35919a5.24446,5.24446,0,0,1-5.33863-5.14859q-.00254-.13972.00238-.27943a5.33625,5.33625,0,1,1,10.67249-.00514v.00514a5.24447,5.24447,0,0,1-5.05681,5.42564Q100.23562,17.36172,100.09585,17.35919Zm3.04179-5.428a3.06527,3.06527,0,1,0-6.1098,0,3.06527,3.06527,0,1,0,6.10981,0Z"></path>
#  <path d="M69.02237,6.69981v5.9l-4.05791-5.9H62.52579v3.56624a5.4542,5.4542,0,0,0-1.44223-2.19612,5.9,5.9,0,0,0-7.97814,0,5.17231,5.17231,0,0,0-1.68479,3.8219,5.45429,5.45429,0,0,0,.8719,3.05491H50.221V6.69981H47.53316V17.26086h5.84758V16.14641a5.6509,5.6509,0,0,0,3.73669,1.31111,5.75581,5.75581,0,0,0,4.07757-1.652,5.32317,5.32317,0,0,0,1.31112-2.14368v3.599H65.207v-5.9l4.12347,5.9h2.38623V6.69981Zm-11.90494,8.142a2.95658,2.95658,0,0,1-2.91068-2.94346,2.89757,2.89757,0,1,1,2.91068,2.94346Z"></path>
#  <path d="M15.48946,8.98771V6.66048H9.46488v4.33979A4.91669,4.91669,0,0,0,7.92431,7.965,5.517,5.517,0,0,0,3.78774,6.69981H.00517V17.26086H4.16141A4.78758,4.78758,0,0,0,7.944,15.94974a4.99538,4.99538,0,0,0,1.5209-2.95V17.1953h6.02458V14.93362h-3.363V12.967h2.91724V10.70527H12.12644V8.98771Zm-11.68861,5.959H2.71262V8.9746H3.78774A2.73028,2.73028,0,0,1,6.8492,11.94428C6.8492,14.0224,5.87242,14.94674,3.80085,14.94674Z"></path>
#  <rect height="24" width="1.63234" x="77.31519"></rect>
#  </svg>
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>
#  </header>
#  <section>
#  <div class="de-u-flex de-u-flexAlignItemsCenter de-u-spaceTop06 de-u-lineHeight1" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Reviews | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357">
#  <span class="de-StarRating de-u-spaceRight06 de-StarRating--small">
#  <span class="de-StarRating-fill" style="width: 92.6%"></span>
#  <span class="de-u-hiddenVisually">
#      (Average rating: 4.63 out of 5 stars,
#    </span>
#  </span>
#  <span class="de-u-textMedium de-u-textSelectNone de-u-textDarkGray de-u-textShrink2 de-u-md-textShrink1">
#    68
#    <span class="de-u-hiddenVisually">
#      Reviews)
#    </span>
#  </span>
#  </div>
#  </section>
#  </a>
#  <div data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Price | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <meta content="USD" itemprop="priceCurrency"/>
#  <link href="https://www.decathlon.com/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="url"/>
#  <link href="https://schema.org/InStock" itemprop="availability"/>
#  <p class="de-ProductTile-price de-u-md-textGrow2 de-u-textMedium de-u-lineHeight4 de-u-spaceBottomNone" id="ProductPrice">
#  <meta content="5,999.00" itemprop="price"/>
#  <span class="de-u-hiddenVisually">Regular price,</span>
#  <span class="js-de-ProductTile-currentPrice">$5,999.00</span>
#  <del class="de-u-padLeft02 de-u-textShrink2">
#  <span class="de-u-hiddenVisually">Regular price, </span>
#  <span class="js-de-ProductTile-crossedOutPrice de-u-hidden">$9,999,999.99</span>
#  </del>
#  </p>
#  </div>
#  <footer class="de-ProductTile-footer js-de-ProductTile-footer">
#  <p class="js-de-ProductTile-inventoryStatus de-u-textRed de-u-textMedium de-u-textShrink1 de-u-spaceBottomNone de-u-hidden">
#
#    Limited Sizes
#  </p>
#  <p class="js-de-DeliveryOptions-freeShipping de-u-spaceNone de-u-textShrink1 de-u-textMedium de-u-hidden">
#  <span>
#    Free shipping
#    <span class="js-de-DeliveryOptions-freeShippingOverThreshold de-u-hidden">over $49</span>
#  </span>
#  </p>
#  <p class="js-de-DeliveryOptions-seeShippingRate de-u-spaceNone de-u-textShrink1 de-u-textMedium">See shipping rate at checkout</p>
#  </footer>
#  </div>
#  </article>,
#  <article -="" 29""data-gtm-event="customer-interaction" class="de-ProductTile de-u-lineHeight3 de-u-bgWhite js-de-ProductTile de-ProductTile--gridAlternate" data-ga4-brand="Rockrider" data-ga4-category="Mountain bike" data-ga4-price="249900" data-gtm-actions="click" data-gtm-category="Regular Collection" data-gtm-id="Mountain Bikes | Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5 - 29 | /collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-product-title="Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/Product" role="listitem">
#  <a "="" -="" 29",="" aria-label="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="js-de-ProductTile-link" href="/collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" image="" of="" tabindex="-1">
#  <section class="de-ProductTile-showcase js-de-ProductTile-showcase">
#  <ul class="de-u-listReset de-u-spaceNone de-ProductTile-flagContainer de-u-textShrink1 de-u-md-textGrow">
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--blackfriday de-u-hidden">
#  <span aria-hidden="true">Black Friday</span>
#  <span class="de-u-hiddenVisually">Black Friday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--newdeal de-u-hidden">
#  <span aria-hidden="true">New Deal</span>
#  <span class="de-u-hiddenVisually">New Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--cybermonday de-u-hidden">
#  <span aria-hidden="true">Cyber Monday</span>
#  <span class="de-u-hiddenVisually">Cyber Monday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-lastCall de-ProductFlag--secondary de-u-hidden">
#  <span aria-hidden="true">Clearance</span>
#  <span class="de-u-hiddenVisually">Clearance product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-sale de-ProductFlag--sale de-u-hidden">
#  <span aria-hidden="true">Deal</span>
#  <span class="de-u-hiddenVisually">Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Best Seller</span>
#  <span class="de-u-hiddenVisually">Best Seller product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--ecogreen de-u-hidden">
#  <span aria-hidden="true">Ecodesign</span>
#  <span class="de-u-hiddenVisually">Ecodesign product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">New</span>
#  <span class="de-u-hiddenVisually">New product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Staff Pick</span>
#  <span class="de-u-hiddenVisually">Staff Pick product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">In The News</span>
#  <span class="de-u-hiddenVisually">In The News product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">Innovation</span>
#  <span class="de-u-hiddenVisually">Innovation product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true"></span>
#  <span class="de-u-hiddenVisually"> product</span>
#  </li>
#  </ul>
#  <div class="de-productTile-showcaseImageContainer">
#  <img "="" -="" 29",="" alt="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="de-ProductTile-showcaseImage de-section5Img-large js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_335x335.jpg?v=1701260391" image="" itemprop="image" loading="lazy" of=""/>
#  <img "="" -="" 29",="" alt="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="de-ProductTile-showcaseImage de-section5Img-desktop js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_264x264.jpg?v=1701260391" image="" itemprop="image" loading="lazy" of=""/>
#  <img "="" -="" 29",="" alt="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="de-ProductTile-showcaseImage de-section5Img-mobile" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-src="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_164x164.jpg?v=1701260391" image="" itemprop="image" loading="lazy" of=""/>
#  </div>
#  </section>
#  </a>
#  <div class="de-ProductTile-info">
#  <div -="" 29",="" aria-label="Colors available" class="de-SwatchObjects de-SwatchObjects--productTile de-u-md-padEnds06 js-de-ProductTile-defaults" data-default-available-variants="4" data-default-compare-at-price="" data-default-image="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_335x335.jpg?v=1701260391" data-default-image-alt="Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" data-default-image2="//www.decathlon.com/cdn/shop/products/8641873-product_image-2111099_9a197799-64f5-41c6-86e6-4df9026643da_335x335.jpg?v=1701260391" data-default-image2-alt="Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" data-default-is-free-shipping="true" data-default-is-last-call="false" data-default-is-sale="false" data-default-price="$2,499.00" data-default-price-varies="false" data-default-total-variants="4" image="" of"="">
#  <a "="" -="" 29",="" class="de-SwatchObjects-item de-ColorSwatches-color js-de-ColorSwatchList-action de-u-hidden" data-available-variants="4" data-color="Black" data-compare-at-price-varies="false" data-compare-at-prices="none==none==none==none" data-gtm-category="Tiles" data-gtm-event="customer-interaction" data-gtm-id="Swatch 1 / 1 | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data
/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <meta content="USD" itemprop="priceCurrency"/>
#  <link href="https://www.decathlon.com/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="url"/>
#  <link href="https://schema.org/InStock" itemprop="availability"/>
#  <p class="de-ProductTile-price de-u-md-textGrow2 de-u-textMedium de-u-lineHeight4 de-u-spaceBottomNone" id="ProductPrice">
#  <meta content="2,499.00" itemprop="price"/>
#  <span class="de-u-hiddenVisually">Regular price,</span>
#  <span class="js-de-ProductTile-currentPrice">$2,499.00</span>
#  <del class="de-u-padLeft02 de-u-textShrink2">
#  <span class="de-u-hiddenVisually">Regular price, </span>
#  <span class="js-de-ProductTile-crossedOutPrice de-u-hidden">$9,999,999.99</span>
#  </del>
#  </p>
#  </div>
#  <footer class="de-ProductTile-footer js-de-ProductTile-footer">
#  <p class="js-de-ProductTile-inventoryStatus de-u-textRed de-u-textMedium de-u-textShrink1 de-u-spaceBottomNone de-u-hidden">
#
#    Limited Sizes
#  </p>
#  <p class="js-de-DeliveryOptions-freeShipping de-u-spaceNone de-u-textShrink1 de-u-textMedium de-u-hidden">
#  <span>
#    Free shipping
#    <span class="js-de-DeliveryOptions-freeShippingOverThreshold de-u-hidden">over $49</span>
#  </span>
#  </p>
#  <p class="js-de-DeliveryOptions-seeShippingRate de-u-spaceNone de-u-textShrink1 de-u-textMedium">See shipping rate at checkout</p>
#  </footer>
#  </div>
#  </article>]

# %% [markdown]
# 2. **Class Selector**:
#    - **`.de-ProductTile`**: This would select all elements with the class `de-ProductTile`.

# %%
soup.select(".de-ProductTile")
# Out:
# [<article class="de-ProductTile de-u-lineHeight3 de-u-bgWhite js-de-ProductTile de-ProductTile--gridAlternate" data-ga4-brand="Rockrider" data-ga4-category="Mountain Bike" data-ga4-price="599900" data-gtm-actions="click" data-gtm-category="Regular Collection" data-gtm-event="customer-interaction" data-gtm-id="Mountain Bikes | Rockrider RACE 900S GX Eagle XC Mountain Bike | /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-product-title="Rockrider RACE 900S GX Eagle XC Mountain Bike" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/Product" role="listitem">
#  <a aria-label="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="js-de-ProductTile-link" href="/collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" tabindex="-1">
#  <section class="de-ProductTile-showcase js-de-ProductTile-showcase">
#  <ul class="de-u-listReset de-u-spaceNone de-ProductTile-flagContainer de-u-textShrink1 de-u-md-textGrow">
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--blackfriday de-u-hidden">
#  <span aria-hidden="true">Black Friday</span>
#  <span class="de-u-hiddenVisually">Black Friday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--newdeal de-u-hidden">
#  <span aria-hidden="true">New Deal</span>
#  <span class="de-u-hiddenVisually">New Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--cybermonday de-u-hidden">
#  <span aria-hidden="true">Cyber Monday</span>
#  <span class="de-u-hiddenVisually">Cyber Monday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-lastCall de-ProductFlag--secondary de-u-hidden">
#  <span aria-hidden="true">Clearance</span>
#  <span class="de-u-hiddenVisually">Clearance product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-sale de-ProductFlag--sale de-u-hidden">
#  <span aria-hidden="true">Deal</span>
#  <span class="de-u-hiddenVisually">Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Best Seller</span>
#  <span class="de-u-hiddenVisually">Best Seller product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--ecogreen de-u-hidden">
#  <span aria-hidden="true">Ecodesign</span>
#  <span class="de-u-hiddenVisually">Ecodesign product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">New</span>
#  <span class="de-u-hiddenVisually">New product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Staff Pick</span>
#  <span class="de-u-hiddenVisually">Staff Pick product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">In The News</span>
#  <span class="de-u-hiddenVisually">In The News product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">Innovation</span>
#  <span class="de-u-hiddenVisually">Innovation product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true"></span>
#  <span class="de-u-hiddenVisually"> product</span>
#  </li>
#  </ul>
#  <div class="de-productTile-showcaseImageContainer">
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-ProductTile-showcaseImage de-section5Img-large js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_335x335.jpg?v=1695294985" itemprop="image" loading="lazy"/>
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-ProductTile-showcaseImage de-section5Img-desktop js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_264x264.jpg?v=1695294985" itemprop="image" loading="lazy"/>
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-ProductTile-showcaseImage de-section5Img-mobile" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_164x164.jpg?v=1695294985" itemprop="image" loading="lazy"/>
#  </div>
#  </section>
#  </a>
#  <div class="de-ProductTile-info">
#  <div aria-label="Colors available" class="de-SwatchObjects de-SwatchObjects--productTile de-u-md-padEnds06 js-de-ProductTile-defaults" data-default-available-variants="4" data-default-compare-at-price="" data-default-image="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_335x335.jpg?v=1695294985" data-default-image-alt="Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of" data-default-image2="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373143_fa092f65-883f-49ce-a1f2-4f16e4c35693_335x335.jpg?v=1695294986" data-default-image2-alt="Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of" data-default-is-free-shipping="true" data-default-is-last-call="false" data-default-is-sale="false" data-default-price="$5,999.00" data-default-price-varies="false" data-default-total-variants="4">
#  <a class="de-SwatchObjects-item de-ColorSwatches-color js-de-ColorSwatchList-action de-u-hidden" data-available-variants="4" data-color="White" data-compare-at-price-varies="false" data-compare-at-prices="none==none==none==none" data-gtm-category="Tiles" data-gtm-event="customer-interaction" data-gtm-id="Swatch 1 / 1 | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" data-image="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_large.jpg?v=1695294985" data-image-alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " data-image2="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373143_fa092f65-883f-49ce-a1f2-4f16e4c35693_large.jpg?v=1695294986" data-image2-alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " data-is-free-shipping="true" data-is-last-call="false" data-is-limited-availability="false" data-is-sale="false" data-price-varies="false" data-prices="599900==599900==599900==599900" data-prices-delimiter="==" data-product-id="7234696904766" data-total-variants="4" href="/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357?variant=40147947749438" itemprop="color" title="Available colors, White, 1 out of 1">
#  <img alt="
#  Rockrider RACE 900S GX Eagle XC Mountain Bike,  Image  of " class="de-SwatchObject-image de-u-block" data-src="//www.decathlon.com/cdn/shop/files/8832747-product_image-2373144_ff28254e-7cdc-4940-8baf-848be00f3561_64x64.jpg?v=1695294985" height="64" loading="lazy" width="64"/>
#  </a>
#  </div>
#  <a class="de-u-linkClean js-de-ProductTile-link js-de-ProductTile-box" href="/collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357">
#  <header class="de-ProductTile-header js-de-ProductTile-header">
#  <svg class="de-ProductTile-brandLogo de-subBrandLogo" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Decathlon Brand | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" height="24" role="img" viewbox="0 0 175.2177 24" width="175.2177">
#  <title>Decathlon Rockrider</title>
#  <path d="M84.77544,6.65392h4.09725a3.5068,3.5068,0,0,1,3.81535,3.4679,3.23846,3.23846,0,0,1-1.96667,2.98935l2.48456,4.09724H90.67547L88.5908,13.64873H87.024v3.55968h-2.2289Zm2.2289,2.0519v2.89757H88.971a1.38319,1.38319,0,0,0,1.475-1.44879,1.38318,1.38318,0,0,0-1.475-1.44878Z"></path>
#  <path d="
#  <polygon points="43.836 13.223 41.063 13.223 41.063 17.261 38.355 17.261 38.355 6.7 41.063 6.7 41.063 10.712 43.836 10.712 43.836 6.7 46.556 6.7 46.556 17.261 43.836 17.261 43.836 13.223 43.836 13.223"></polygon>
#  <path d="M69.02237,6.69981v5.9l-4.05791-5.9H62.52579v3.56624a5.4542,5.4542,0,0,0-1.44223-2.19612,5.9,5.9,0,0,0-7.97814,0,5.17231,5.17231,0,0,0-1.68479,3.8219,5.45429,5.45429,0,0,0,.8719,3.05491H50.221V6.69981H47.53316V17.26086h5.84758V16.14641a5.6509,5.6509,0,0,0,3.73669,1.31111,5.75581,5.75581,0,0,0,4.07757-1.652,5.32317,5.32317,0,0,0,1.31112-2.14368v3.599H65.207v-5.9l4.12347,5.9h2.38623V6.69981Zm-11.90494,8.142a2.95658,2.95658,0,0,1-2.91068-2.94346,2.89757,2.89757,0,1,1,2.91068,2.94346Z"></path>
#  <path d="M15.48946,8.98771V6.66048H9.46488v4.33979A4.91669,4.91669,0,0,0,7.92431,7.965,5.517,5.517,0,0,0,3.78774,6.69981H.00517V17.26086H4.16141A4.78758,4.78758,0,0,0,7.944,15.94974a4.99538,4.99538,0,0,0,1.5209-2.95V17.1953h6.02458V14.93362h-3.363V12.967h2.91724V10.70527H12.12644V8.98771Zm-11.68861,5.959H2.71262V8.9746H3.78774A2.73028,2.73028,0,0,1,6.8492,11.94428C6.8492,14.0224,5.87242,14.94674,3.80085,14.94674Z"></path>
#  <rect height="24" width="1.63234" x="77.31519"></rect>
#  </svg>
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>
#  </header>
#  <section>
#  <div class="de-u-flex de-u-flexAlignItemsCenter de-u-spaceTop06 de-u-lineHeight1" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Reviews | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357">
#  <span class="de-StarRating de-u-spaceRight06 de-StarRating--small">
#  <span class="de-StarRating-fill" style="width: 92.6%"></span>
#  <span class="de-u-hiddenVisually">
#      (Average rating: 4.63 out of 5 stars,
#    </span>
#  </span>
#  <span class="de-u-textMedium de-u-textSelectNone de-u-textDarkGray de-u-textShrink2 de-u-md-textShrink1">
#    68
#    <span class="de-u-hiddenVisually">
#      Reviews)
#    </span>
#  </span>
#  </div>
#  </section>
#  </a>
#  <div data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Price | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <meta content="USD" itemprop="priceCurrency"/>
#  <link href="https://www.decathlon.com/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="url"/>
#  <link href="https://schema.org/InStock" itemprop="availability"/>
#  <p class="de-ProductTile-price de-u-md-textGrow2 de-u-textMedium de-u-lineHeight4 de-u-spaceBottomNone" id="ProductPrice">
#  <meta content="5,999.00" itemprop="price"/>
#  <span class="de-u-hiddenVisually">Regular price,</span>
#  <span class="js-de-ProductTile-currentPrice">$5,999.00</span>
#  <del class="de-u-padLeft02 de-u-textShrink2">
#  <span class="de-u-hiddenVisually">Regular price, </span>
#  <span class="js-de-ProductTile-crossedOutPrice de-u-hidden">$9,999,999.99</span>
#  </del>
#  </p>
#  </div>
#  <footer class="de-ProductTile-footer js-de-ProductTile-footer">
#  <p class="js-de-ProductTile-inventoryStatus de-u-textRed de-u-textMedium de-u-textShrink1 de-u-spaceBottomNone de-u-hidden">
#
#    Limited Sizes
#  </p>
#  <p class="js-de-DeliveryOptions-freeShipping de-u-spaceNone de-u-textShrink1 de-u-textMedium de-u-hidden">
#  <span>
#    Free shipping
#    <span class="js-de-DeliveryOptions-freeShippingOverThreshold de-u-hidden">over $49</span>
#  </span>
#  </p>
#  <p class="js-de-DeliveryOptions-seeShippingRate de-u-spaceNone de-u-textShrink1 de-u-textMedium">See shipping rate at checkout</p>
#  </footer>
#  </div>
#  </article>,
#  <article -="" 29""data-gtm-event="customer-interaction" class="de-ProductTile de-u-lineHeight3 de-u-bgWhite js-de-ProductTile de-ProductTile--gridAlternate" data-ga4-brand="Rockrider" data-ga4-category="Mountain bike" data-ga4-price="249900" data-gtm-actions="click" data-gtm-category="Regular Collection" data-gtm-id="Mountain Bikes | Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5 - 29 | /collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-product-title="Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/Product" role="listitem">
#  <a "="" -="" 29",="" aria-label="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="js-de-ProductTile-link" href="/collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" image="" of="" tabindex="-1">
#  <section class="de-ProductTile-showcase js-de-ProductTile-showcase">
#  <ul class="de-u-listReset de-u-spaceNone de-ProductTile-flagContainer de-u-textShrink1 de-u-md-textGrow">
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--blackfriday de-u-hidden">
#  <span aria-hidden="true">Black Friday</span>
#  <span class="de-u-hiddenVisually">Black Friday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--newdeal de-u-hidden">
#  <span aria-hidden="true">New Deal</span>
#  <span class="de-u-hiddenVisually">New Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--cybermonday de-u-hidden">
#  <span aria-hidden="true">Cyber Monday</span>
#  <span class="de-u-hiddenVisually">Cyber Monday product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-lastCall de-ProductFlag--secondary de-u-hidden">
#  <span aria-hidden="true">Clearance</span>
#  <span class="de-u-hiddenVisually">Clearance product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 js-de-ProductFlag-sale de-ProductFlag--sale de-u-hidden">
#  <span aria-hidden="true">Deal</span>
#  <span class="de-u-hiddenVisually">Deal product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Best Seller</span>
#  <span class="de-u-hiddenVisually">Best Seller product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--ecogreen de-u-hidden">
#  <span aria-hidden="true">Ecodesign</span>
#  <span class="de-u-hiddenVisually">Ecodesign product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">New</span>
#  <span class="de-u-hiddenVisually">New product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true">Staff Pick</span>
#  <span class="de-u-hiddenVisually">Staff Pick product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">In The News</span>
#  <span class="de-u-hiddenVisually">In The News product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--tertiary de-u-hidden">
#  <span aria-hidden="true">Innovation</span>
#  <span class="de-u-hiddenVisually">Innovation product</span>
#  </li>
#  <li class="de-ProductFlag de-u-textSemibold de-u-textShrink1 de-ProductFlag--primary de-u-hidden">
#  <span aria-hidden="true"></span>
#  <span class="de-u-hiddenVisually"> product</span>
#  </li>
#  </ul>
#  <div class="de-productTile-showcaseImageContainer">
#  <img "="" -="" 29",="" alt="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="de-ProductTile-showcaseImage de-section5Img-large js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_335x335.jpg?v=1701260391" image="" itemprop="image" loading="lazy" of=""/>
#  <img "="" -="" 29",="" alt="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="de-ProductTile-showcaseImage de-section5Img-desktop js-de-ProductTile-featureImage" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-show-secondary-image="" data-src="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_264x264.jpg?v=1701260391" image="" itemprop="image" loading="lazy" of=""/>
#  <img "="" -="" 29",="" alt="
#  Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" class="de-ProductTile-showcaseImage de-section5Img-mobile" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Hero Image | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" data-src="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_164x164.jpg?v=1701260391" image="" itemprop="image" loading="lazy" of=""/>
#  </div>
#  </section>
#  </a>
#  <div class="de-ProductTile-info">
#  <div -="" 29",="" aria-label="Colors available" class="de-SwatchObjects de-SwatchObjects--productTile de-u-md-padEnds06 js-de-ProductTile-defaults" data-default-available-variants="4" data-default-compare-at-price="" data-default-image="//www.decathlon.com/cdn/shop/products/8641873-product_image-2097849_8747eb26-d2d9-4d83-b6a5-d5ac2b6b0d46_335x335.jpg?v=1701260391" data-default-image-alt="Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" data-default-image2="//www.decathlon.com/cdn/shop/products/8641873-product_image-2111099_9a197799-64f5-41c6-86e6-4df9026643da_335x335.jpg?v=1701260391" data-default-image2-alt="Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" data
#  <path d="M15.48946,8.98771V6.66048H9.46488v4.33979A4.91669,4.91669,0,0,0,7.92431,7.965,5.517,5.517,0,0,0,3.78774,6.69981H.00517V17.26086H4.16141A4.78758,4.78758,0,0,0,7.944,15.94974a4.99538,4.99538,0,0,0,1.5209-2.95V17.1953h6.02458V14.93362h-3.363V12.967h2.91724V10.70527H12.12644V8.98771Zm-11.68861,5.959H2.71262V8.9746H3.78774A2.73028,2.73028,0,0,1,6.8492,11.94428C6.8492,14.0224,5.87242,14.94674,3.80085,14.94674Z"></path>
#  <rect height="24" width="1.63234" x="77.31519"></rect>
#  </svg>
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>
#  </header>
#  <section>
#  <div class="de-u-flex de-u-flexAlignItemsCenter de-u-spaceTop06 de-u-lineHeight1" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Reviews | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990">
#  <span class="de-StarRating de-u-spaceRight06 de-StarRating--small">
#  <span class="de-StarRating-fill" style="width: 89.4%"></span>
#  <span class="de-u-hiddenVisually">
#      (Average rating: 4.47 out of 5 stars,
#    </span>
#  </span>
#  <span class="de-u-textMedium de-u-textSelectNone de-u-textDarkGray de-u-textShrink2 de-u-md-textShrink1">
#    236
#    <span class="de-u-hiddenVisually">
#      Reviews)
#    </span>
#  </span>
#  </div>
#  </section>
#  </a>
#  <div data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Price | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="offers" itemscope="" itemtype="https://schema.org/Offer">
#  <meta content="USD" itemprop="priceCurrency"/>
#  <link href="https://www.decathlon.com/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="url"/>
#  <link href="https://schema.org/InStock" itemprop="availability"/>
#  <p class="de-ProductTile-price de-u-md-textGrow2 de-u-textMedium de-u-lineHeight4 de-u-spaceBottomNone" id="ProductPrice">
#  <meta content="2,499.00" itemprop="price"/>
#  <span class="de-u-hiddenVisually">Regular price,</span>
#  <span class="js-de-ProductTile-currentPrice">$2,499.00</span>
#  <del class="de-u-padLeft02 de-u-textShrink2">
#  <span class="de-u-hiddenVisually">Regular price, </span>
#  <span class="js-de-ProductTile-crossedOutPrice de-u-hidden">$9,999,999.99</span>
#  </del>
#  </p>
#  </div>
#  <footer class="de-ProductTile-footer js-de-ProductTile-footer">
#  <p class="js-de-ProductTile-inventoryStatus de-u-textRed de-u-textMedium de-u-textShrink1 de-u-spaceBottomNone de-u-hidden">
#
#    Limited Sizes
#  </p>
#  <p class="js-de-DeliveryOptions-freeShipping de-u-spaceNone de-u-textShrink1 de-u-textMedium de-u-hidden">
#  <span>
#    Free shipping
#    <span class="js-de-DeliveryOptions-freeShippingOverThreshold de-u-hidden">over $49</span>
#  </span>
#  </p>
#  <p class="js-de-DeliveryOptions-seeShippingRate de-u-spaceNone de-u-textShrink1 de-u-textMedium">See shipping rate at checkout</p>
#  </footer>
#  </div>
#  </article>]

# %% [markdown]
# To combine both, we can have `soup.select("tagname.classname")`

# %% [markdown]
# Without CSS selectors we did:

# %%
# Extracting all links within <a> tags and class 'de-u-linkClean js-de-ProductTile-link'
for index, link in enumerate(soup.find_all('a', class_='js-de-ProductTile-link')):
    if index%2 == 0:
        print(link.get('href'))
# Out:
# /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357
# /collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990

# %% [markdown]
# Equivalently, using CSS selectors, which is a universal syntax, you can try and find `tag_name.class_name`. If class name has spaces, they must be changed by `.`

# %%
# Extracting all links within <a> tags and class 'de-u-linkClean js-de-ProductTile-link'
for link in soup.select('a.de-u-linkClean.js-de-ProductTile-link'):
    print(link.get('href'))
# Out:
# /collections/mountain-bikes/products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357
# /collections/mountain-bikes/products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990

# %% [markdown]
# 3. **Descendant Selector**:
#    - **`.de-ProductTile .de-ProductTile-title`**: This would select all elements with the class `de-ProductTile-title` that are descendants of elements with the class `de-ProductTile`.
#    - **`article h4`**: This would select all `<h4>` elements that are descendants of `<article>` elements.

# %%
soup.select(".de-ProductTile .de-ProductTile-title")
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>]

# %%
soup.select("article h4")
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>,
#  <h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-am-fifty_s-12-speed-full-suspension-all-mountain-bike-275-29-331990" itemprop="name">
#            Rockrider AM Fifty_S 12-Speed Full Suspension All-Mountain Bike 27.5" - 29"
#          </h4>]

# %%
# how many spans?
len(soup.select("span"))
# Out:
# 198

# %%
# how many spans inside spans?
len(soup.select("span span"))
# Out:
# 12

# %%
# how many spans inside spans inside spans?
len(soup.select("span span span"))
# Out:
# 0

# %%
# how many span inside div inside div inside div ...
len(soup.select("div div div div div div div div span"))
# Out:
# 90

# %% [markdown]
# [Beautiful Soup selectors](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %% [markdown]
# You can also use a combination of `find`, `find_all`, and `select` methods to navigate and locate the elements you're interested in more efficiently. Here's how you can use them together:
#
# 1. **Using `find` or `find_all` to Narrow Down the Search Scope**:
#
#    Initially, you can use `find` or `find_all` to narrow down your search to a specific section of the HTML document.
#
#    ```python
#    section = soup.find('div', class_='product-section')
#    ```
#
# 2. **Using `select` to Further Locate Elements**:
#
#    After narrowing down the section, you can use the `select` method to locate elements using CSS selectors, which allow for more complex queries. The `select` method can be used on a BeautifulSoup object or on a Tag object (like the one retrieved in step 1).
#
#    ```python
#    product_links = section.select('a.product-link')
#    ```
#
# In this snippet:
# - First, we locate a section of the webpage using `find`.
# - Then, within that section, we locate all `a` elements with the class `'product-link'` using `select`.

# %%
first_product = soup.find('article', class_='de-ProductTile')
first_product.select('h4.de-ProductTile-title')
# Out:
# [<h4 class="de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2" data-gtm-actions="click" data-gtm-category="Tiles" data-gtm-delegate="child" data-gtm-event="customer-interaction" data-gtm-id="Product Title | /products/rockrider-race-900s-gx-eagle-xc-mountain-bike-350357" itemprop="name">
#            Rockrider RACE 900S GX Eagle XC Mountain Bike
#          </h4>]

# %%
# Since its a list we need to access the element to get the text
first_product.select('h4.de-ProductTile-title')[0].text
# Out:
# '\n          Rockrider RACE 900S GX Eagle XC Mountain Bike\n        '

# %% [markdown]
# ### More examples

# %% [markdown]
# #### BBC

# %% [markdown]
# Lets scrape the BBC to gather some information.

# %% [markdown]
# We'll get the hyperlinks to images from the BBC website.

# %%
response = requests.get("https://www.bbc.com/")
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
img_tags = soup.find_all("img") # We get all the image elements

# %%
len(img_tags) # Lets see how many we got
# Out:
# 152

# %%
img_tags[1] # For example, lets look at the second one to see how we can get the actual URL
# Out:
# <img alt="Burial scene" class="sc-a898728c-0 kbvxap" loading="lazy" sizes="96vw" src="https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp" srcset="https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp 240w,https://ichef.bbci.co.uk/ace/standard/320/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp 320w,https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp 480w,https://ichef.bbci.co.uk/ace/standard/640/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp 640w,https://ichef.bbci.co.uk/ace/standard/800/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp 800w,https://ichef.bbci.co.uk/ace/standard/1024/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp 1024w,https://ichef.bbci.co.uk/ace/standard/1536/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp 1536w"/>

# %%
# We can use the get method to get the src attribute which contains the URL to the image
img_tags[1].get("src")
# Out:
# 'https://ichef.bbci.co.uk/ace/standard/480/cpsprodpb/F120/production/_132782716_5a28c7ee1bc742246fc4a2c5dd825fa936f1cca20_42_7908_44481000x563.jpg.webp'

# %%
# Find the nav element with the specified class
nav_element = soup.find('nav', class_='orbit-header-links international')

# Find all span elements inside the nav element
menu_names = [span.get_text() for span in nav_element.find_all('span')]

# Print the menu names
for name in menu_names:
    print(name)

# %% [markdown]
# ## Comments

# %% [markdown]
# It's always recommended to check for the availability of an **API** before resorting to web scraping for the following reasons:
#  * It is generally much easier to use
#  * APIs are usually well-documented
#  * Utilizing APIs is often preferred by server administrators
#
# Refer to the `robots.txt` file on a website (by doing `www.example.com/robots.txt`) to understand the server's guidelines and limitations regarding web scraping.

# %% [markdown]
# ## Summary

# %% [markdown]
# 1. **Web Technologies**:
#    - **HTML**: This is the standard markup language that holds the content of the webpage. It is the primary target when we engage in web scraping.
#    - **CSS**: Cascading Style Sheets are used to describe the look and formatting of a document written in HTML.
#    - **JavaScript**: This is a scripting language used to create and interactive and dynamic website content.
#
# 2. **HTML Structure**:
#    - **Hierarchical**: HTML documents are structured hierarchically, meaning elements are nested within other elements, forming a tree-like structure.
#    - **Tags**: These are the building blocks of HTML, defining elements that hold different types of content.
#    - **Attributes**: HTML tags can have attributes, which define properties of an element and are used to set various characteristics such as class, ID, and style.
#
# 3. **Web Scraping Tools**:
#    - **Requests**: A Python library that allows you to send HTTP requests to get the HTML content of a webpage.
#    - **Beautiful Soup**: A Python library that facilitates the programmatic analysis of HTML, helping in parsing the HTML and navigating the parse tree.
#    - **Selenium**: In cases where the webpage content is dynamic and generated using JavaScript, tools like Selenium are often used. Selenium can interact with JavaScript to load dynamic content, making it accessible for scraping.
#
# 4. **Finding and Selecting Elements**:
#    - **Selection by Tag, Class, and ID**: We can find elements using various attributes such as their tag name, class name, or ID.
#    - **CSS Selectors**: These are patterns used to select elements more complexly, leveraging the relationships between different elements to find them in numerous ways.

# %% [markdown]
# ## Further materials

# %% [markdown]
# [Web archive](http://web.archive.org/): Find the historical state of webpages in the past!

# %% [markdown]
# ### How to Solve a 403 Error
#
# When you get a `403` status code in response to a web request, it means "Forbidden." The server understands your request, but it refuses to fulfill it. This is often a measure by websites to prevent web scraping or automated access.
#
# Here's why you might get a `403 Forbidden` error:
#
# 1. **User-Agent**: Many websites block requests that don't have a standard web browser User-Agent. The default User-Agent of the `requests` library often gets blocked.
# 2. **Robots.txt**: This is a file websites use to guide web crawlers about which pages or sections of the site shouldn't be processed or scanned. Respect it.
# 3. **Rate Limiting**: Websites might block you if you make too many requests in a short period.
# And more...
#
# To solve it, try the following, starting from the user-agent:
#
# 1. **Change the User-Agent**:
#    You can mimic a request from a web browser by setting a User-Agent header.
#    ```python
#    headers = {
#        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
#    }
#    response = requests.get(url, headers=headers)
#    ```
#
# 2. **Use a Web Scraper Library**:
#    Libraries like Scrapy or Selenium can help bypass restrictions, especially when JavaScript rendering is involved.
#
# 3. **Respect `robots.txt`**:
#    Always check `https://www.example.com/robots.txt` (replace `example.com` with the website's domain) to see which URLs you're allowed to access.
#
# 4. **Rate Limiting**:
#    Implement delays in your requests using `time.sleep(seconds)` to avoid hitting rate limits.
#
# 5. **Use Proxies or VPN**:
#    Rotate IP addresses or use a VPN service if the server has blocked your IP.
#
# 6. **Sessions & Cookies**:
#    Some websites might require maintaining sessions or handling cookies.
